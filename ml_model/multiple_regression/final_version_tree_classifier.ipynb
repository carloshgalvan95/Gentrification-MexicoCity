# %% [markdown]
# # import Dependencies

# %%
# Import dependencies for multiple regression
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error
import re


# Import dependencies for google maps API
#from config import g_key
import gmaps
import requests
import geopy.distance

# Import dependencies for classifier models
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn import tree
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %% [markdown]
# # Data Transformation

# %%
# Import csv files to DataFrames
catastro_df = pd.read_csv('../../db_catastro.csv')
starbucks_df = pd.read_csv('../../MexicoCityStarbucks.csv')
airbnb_df = pd.read_csv('../../Airbnb.csv')

# %%
airbnb_df
# Out:
#       last_scraped                                               name  \
# 0        9/22/2022                                        Villa Dante
# 1        9/22/2022                Area Sta.Fe,IberoABC Hospital Rooms
# 2        9/23/2022            Classic but Modern Apartment in Condesa
# 3        9/23/2022                                  CONDESA HAUS  B&B
# 4        9/22/2022                 Live Mexico City Like a Small Town
# ...            ...                                                ...
# 22943    9/22/2022              Depa seguro a 10 mns en auto del AICM
# 22944    9/22/2022  Comoda habitación con vista e iluminación natural
# 22945    9/22/2022                 Beautiful house gardens & terraces
# 22946    9/22/2022  Amplio Dpto a 5 min de Av P. de las Palmas/Par...
# 22947    9/22/2022  Dpto Equipado a 3 min P. de las Palmas!Gym/Par...
#
#       neighbourhood_cleansed   latitude  longitude    price
# 0      Cuajimalpa de Morelos  19.382830 -99.271780   4001.0
# 1      Cuajimalpa de Morelos  19.353790 -99.284590    500.0
# 2                 Cuauhtémoc  19.418240 -99.175600    599.0
# 3                 Cuauhtémoc  19.411620 -99.177940  18000.0
# 4              Benito Juárez  19.384680 -99.177080    740.0
# ...                      ...        ...        ...      ...
# 22943      Gustavo A. Madero  19.465703 -99.051118    450.0
# 22944         Miguel Hidalgo  19.421690 -99.245990    750.0
# 22945         Miguel Hidalgo  19.430260 -99.238160   5041.0
# 22946         Miguel Hidalgo  19.427120 -99.224520   1100.0
# 22947         Miguel Hidalgo  19.427380 -99.224400    959.0
#
# [22948 rows x 6 columns]

# %%
starbucks_df
# Out:
#          Brand                                     Street Address  \
# 0    Starbucks  de la Industria Militar 1296,, Lomas de Chamiz...
# 1    Starbucks  Homero n.503, Col. Chapultepec Morales, Del. M...
# 2    Starbucks                        Palanque s/n, Col. Narvarte
# 3    Starbucks               AV SAN JERONIMO 819 COL SAN JERONIMO
# 4    Starbucks               RENATO LEDUC 224 COL TORIELLO GUERRA
# ..         ...                                                ...
# 224  Starbucks  Eje 1 Nte Mosqueta 259 Buenavista, Eje 1 Nte M...
# 225  Starbucks  Shiller esquina Masaryk 111, Polanco, Shiller ...
# 226  Starbucks  Calz. Las Aguilas 1953 Col. Axomiatla, Del. Al...
# 227  Starbucks  Av. Leyes de Reforma esq. Baratillo, Col. Ejid...
# 228  Starbucks  Paseo de la Reforma 180, Reforma esquina Insur...
#
#                  City State/Province Country  Postcode  Longitude  Latitude
# 0    Ciudad de Mexico            DIF      MX      5129     -99.26     19.39
# 1                  DF            DIF      MX     11570     -99.19     19.44
# 2                  DF            DIF      MX      1030     -99.15     19.40
# 3    DISTRITO FEDERAL            DIF      MX     10200     -99.23     19.32
# 4    DISTRITO FEDERAL            DIF      MX     14050     -99.16     19.30
# ..                ...            ...     ...       ...        ...       ...
# 224         Mexico DF            DIF      MX      6350     -99.15     19.45
# 225         Mexico DF            DIF      MX     11550     -99.19     19.43
# 226         Mexico DF            DIF      MX     11520     -99.25     19.34
# 227         Mexico DF            DIF      MX      9040     -99.09     19.38
# 228         Mexico DF            DIF      MX      6600     -99.16     19.43
#
# [229 rows x 8 columns]

# %%
catastro_df
# Out:
#       Unnamed: 0                         nombre_col  num_code  \
# 0              0                         19 DE MAYO      1210
# 1              1                       1RA VICTORIA      1150
# 2              2       1RA VICTORIA SECCION BOSQUES      1150
# 3              3         2DA  JALALPA TEPITO (AMPL)      1260
# 4              4                2DA EL PIRUL (AMPL)      1210
# ...          ...                                ...       ...
# 1784          73                          GUADALUPE     16900
# 1785          74           NATIVITAS LA JOYA (AMPL)     16900
# 1786          75  SAN FRANCISCO TLALNEPANTLA (PBLO)     16910
# 1787          76     SANTA CECILIA TEPETLAPA (PBLO)     16880
# 1788          77     SAN LUIS TLAXIALTEMALCO (PBLO)     16610
#
#       prom_valor_unitario_suelo    latitud   longitud        alcaldia estado
# 0                   1404.400000  19.361649 -99.253530  Álvaro Obregón   CDMX
# 1                   2061.619503  19.386686 -99.201985  Álvaro Obregón   CDMX
# 2                   1788.360000  19.387826 -99.197446  Álvaro Obregón   CDMX
# 3                   1063.626266  19.375080 -99.233736  Álvaro Obregón   CDMX
# 4                   1320.710000  19.379745 -99.242231  Álvaro Obregón   CDMX
# ...                         ...        ...        ...             ...    ...
# 1784                 420.703636  19.218264 -99.120799      Xochimilco   CDMX
# 1785                 711.580672  19.237250 -99.093782      Xochimilco   CDMX
# 1786                 338.647387  19.197937 -99.122385      Xochimilco   CDMX
# 1787                 534.238763  19.217187 -99.099325      Xochimilco   CDMX
# 1788                 667.526340  19.256973 -99.035680      Xochimilco   CDMX
#
# [1789 rows x 8 columns]

# %% [markdown]
# # Parse data to locate nearby Airbnbs

# %%
# Create columns to store number of Airbnb and Starbucks nearby
catastro_df['no_airbnb'] = ''
catastro_df['no_starbucks'] = ''
catastro_df['airbnb_mean_price'] = ''
catastro_df = catastro_df.reset_index()

# Declare for loop to iterate over every row of catastro_df to compare distance radius
for df_index, row in catastro_df.iterrows():
    
    #Declare variable for name of the Neighbourhood
    nombre_col = row['nombre_col']
    # Declare counter variable to hold number of Airbnbs and Starbucks nearby
    no_airbnb = 0
    no_starbucks = 0
    airbnb_price = 0
    holder_price = 0
    mean_price = 0
    
    # Get Latitude and Longitude of the row
    lat_cat = row['latitud']
    lng_cat = row['longitud']
    
    # Pair coordinates
    catastro_loc = (lat_cat,lng_cat)

    # With every catastro_df row, iterate and compare distances between each row of Airbnbs
    for bnb_index, row in airbnb_df.iterrows():
        
        # Get Latitude and Longitude of the row
        lat_bnb = row['latitude']
        lng_bnb = row['longitude']
        
        # Pair coordinates
        airbnb_loc = (lat_bnb,lng_bnb)
        
        # Using geopy.distance module, compare both coordinate to determine distance between them
        distancia = geopy.distance.geodesic(catastro_loc, airbnb_loc).m
        
        # Create conditional to add 1 to the counter if Airbnb is within 500m of Catastro_df row location
        if distancia < 800:
            airbnb_price = row['price']
            holder_price = airbnb_price + holder_price
            no_airbnb = no_airbnb + 1
    
    # After parsing on every row, append number of airbnbs nearby
    catastro_df.loc[df_index, 'no_airbnb'] = no_airbnb
    if no_airbnb > 0:
        mean_price = holder_price / no_airbnb
        catastro_df.loc[df_index, 'airbnb_mean_price'] = mean_price
    
    # With every catastro_df row, iterate and compare distances between each row of Starbucks
    for starbucks_index, row in starbucks_df.iterrows():
        try: 
            # Get Latitude and Longitude of the row
            lat_starbucks = row['Latitude']
            lng_starbucks = row['Longitude']
        
            # Pair Coordinates
            starbucks_loc = (lat_starbucks,lng_starbucks)
        
            # Using geopy.distance module, compare both coordinate to determine distance between them
            distancia_starbucks = geopy.distance.geodesic(catastro_loc, starbucks_loc).m
        
            # Create conditional to add 1 to the counter if Starbucks is within 500m of Catastro_df row location
            if distancia_starbucks < 700:
                no_starbucks = no_starbucks + 1
                
        except(ValueError):
            print('Value Error for', row['Street Address'])
    
    # After parsing on every row, append number of Starbucks nearby
    catastro_df.loc[df_index, 'no_starbucks'] = no_starbucks
    print('-----------------------------------')
    print(nombre_col)
    print(f'#{no_airbnb} Airbnbs found')
    print(f'Airbnb average cost: ${mean_price}')
    print(f'#{no_starbucks} Starbucks found')
    print('-----------------------------------')
# Out:
# -----------------------------------
# 19 DE MAYO
# #19 Airbnbs found
# Airbnb average cost: $756.6842105263158
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# 1RA VICTORIA
# #29 Airbnbs found
# Airbnb average cost: $1033.3103448275863
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# 1RA VICTORIA SECCION BOSQUES
# #74 Airbnbs found
# Airbnb average cost: $944.6486486486486
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# 2DA  JALALPA TEPITO (AMPL)
# #3 Airbnbs found
# Airbnb average cost: $506.3333333333333
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# 2DA EL PIRUL (AMPL)
# #11 Airbnbs found
# Airbnb average cost: $878.5454545454545
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# ABRAHAM GONZALEZ
# #12 Airbnbs found
# Airbnb average cost: $672.25
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# ACUEDUCTO
# #8 Airbnbs found
# Airbnb average cost: $638.875
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# ACUILOTLA
# #23 Airbnbs found
# Airbnb average cost: $498.5652173913044
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# AGUILAS 3ER PARQUE
# #12 Airbnbs found
# Airbnb average cost: $1425.0833333333333
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# AGUILAS PILARES
# #22 Airbnbs found
# Airbnb average cost: $898.7727272727273
# #1 Starbucks found
# -----------------------------------
# -----------------------------------
# ALCANTARILLA
# #32 Airbnbs found
# Airbnb average cost: $790.5
# #2 Starbucks found
# -----------------------------------
# -----------------------------------
# ALFALFAR
# #24 Airbnbs found
# Airbnb average cost: $1049.375
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# ALFONSO XIII
# #75 Airbnbs found
# Airbnb average cost: $814.9333333333333
# #1 Starbucks found
# -----------------------------------
# -----------------------------------
# ALPES
# #95 Airbnbs found
# Airbnb average cost: $1378.7684210526315
# #1 Starbucks found
# -----------------------------------
# -----------------------------------
# ALPES (AMPL)
# #12 Airbnbs found
# Airbnb average cost: $803.25
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# ARBOLEDAS POLITOCO
# #18 Airbnbs found
# Airbnb average cost: $596.8333333333334
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# ARCOS DE CENTENARIO
# #10 Airbnbs found
# Airbnb average cost: $1467.9
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# ARTURO GAMIZ
# #34 Airbnbs found
# Airbnb average cost: $879.2941176470588
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# ARTURO MARTINEZ
# #12 Airbnbs found
# Airbnb average cost: $394.6666666666667
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# ARVIDE
# #11 Airbnbs found
# Airbnb average cost: $987.9090909090909
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# ATLAMAXAC
# #27 Airbnbs found
# Airbnb average cost: $721.925925925926
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# ATLAMAYA
# #40 Airbnbs found
# Airbnb average cost: $1425.725
# #1 Starbucks found
# -----------------------------------
# -----------------------------------
# AVE REAL
# #20 Airbnbs found
# Airbnb average cost: $637.9
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# AVE REAL (AMPL)
# #22 Airbnbs found
# Airbnb average cost: $691.1363636363636
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# AXOTLA
# #119 Airbnbs found
# Airbnb average cost: $1301.0840336134454
# #4 Starbucks found
# -----------------------------------
# -----------------------------------
# BALCONES DE CEHUAYO
# #20 Airbnbs found
# Airbnb average cost: $840.8
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# BARRIO NORTE
# #2 Airbnbs found
# Airbnb average cost: $394.5
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# BATALLON DE SAN PATRICIO (U HAB)
# #14 Airbnbs found
# Airbnb average cost: $477.42857142857144
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# BEJERO
# #20 Airbnbs found
# Airbnb average cost: $909.7
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# BELEN DE LAS FLORES
# #1 Airbnbs found
# Airbnb average cost: $300.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# BELEN DE LAS FLORES (U HAB)
# #15 Airbnbs found
# Airbnb average cost: $409.6666666666667
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# BELEN DE LAS FLORES SECCION RELLENO
# #6 Airbnbs found
# Airbnb average cost: $745.6666666666666
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# BELEN DE LAS FLORES_
# #13 Airbnbs found
# Airbnb average cost: $1101.3076923076924
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# BELLA VISTA
# #49 Airbnbs found
# Airbnb average cost: $988.0408163265306
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# BONANZA
# #5 Airbnbs found
# Airbnb average cost: $411.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# BOSQUES DE TARANGO
# #51 Airbnbs found
# Airbnb average cost: $715.1372549019608
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# CAADA DEL OLIVAR (U HAB)
# #20 Airbnbs found
# Airbnb average cost: $456.3
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# CALZADA JALALPA
# #15 Airbnbs found
# Airbnb average cost: $1307.6
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# CAMPO DE TIRO LOS GAMITOS
# #10 Airbnbs found
# Airbnb average cost: $551.4
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# CANUTILLO 3RA SECCION
# #17 Airbnbs found
# Airbnb average cost: $1904.4705882352941
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# CANUTILLO PREDIO LA PRESA
# #15 Airbnbs found
# Airbnb average cost: $795.7333333333333
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# CAROLA
# #77 Airbnbs found
# Airbnb average cost: $930.025974025974
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# CEDRO CHICO
# #24 Airbnbs found
# Airbnb average cost: $728.5
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# CHIMALISTAC
# #129 Airbnbs found
# Airbnb average cost: $1272.5813953488373
# #2 Starbucks found
# -----------------------------------
# -----------------------------------
# COLINAS DE TARANGO
# #14 Airbnbs found
# Airbnb average cost: $1119.642857142857
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# COLINAS DEL SUR
# #15 Airbnbs found
# Airbnb average cost: $2128.2
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# CONCIENCIA PROLETARIA
# #12 Airbnbs found
# Airbnb average cost: $1348.25
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# COOPERATIVA CEHUAYO
# #22 Airbnbs found
# Airbnb average cost: $663.1363636363636
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# CORPUS CHRISTY
# #21 Airbnbs found
# Airbnb average cost: $601.1904761904761
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# CORPUS CURISTY AMPL XOCOMECATLA
# #18 Airbnbs found
# Airbnb average cost: $596.8333333333334
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# COVE
# #26 Airbnbs found
# Airbnb average cost: $810.4230769230769
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# CRISTO REY
# #32 Airbnbs found
# Airbnb average cost: $894.90625
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# DE TARANGO (RCNDA)
# #13 Airbnbs found
# Airbnb average cost: $1178.7692307692307
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# DESARROLLO URBANO
# #13 Airbnbs found
# Airbnb average cost: $1495.7692307692307
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# DOS RIOS
# #18 Airbnbs found
# Airbnb average cost: $761.7777777777778
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# EL ARBOL
# #6 Airbnbs found
# Airbnb average cost: $524.1666666666666
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# EL BATAN
# #19 Airbnbs found
# Airbnb average cost: $756.1052631578947
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# EL BOSQUE
# #42 Airbnbs found
# Airbnb average cost: $1052.6666666666667
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# EL BOSQUE 2DA SECCION (AMPL)
# #32 Airbnbs found
# Airbnb average cost: $907.625
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# EL BOSQUE SECCION TORRES
# #52 Airbnbs found
# Airbnb average cost: $982.4807692307693
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# EL CAPULIN
# #7 Airbnbs found
# Airbnb average cost: $674.8571428571429
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# EL CAPULIN (AMPL)
# #6 Airbnbs found
# Airbnb average cost: $737.3333333333334
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# EL CUERNITO
# #11 Airbnbs found
# Airbnb average cost: $412.72727272727275
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# EL MIRADOR
# #22 Airbnbs found
# Airbnb average cost: $643.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# EL PARAISO
# #5 Airbnbs found
# Airbnb average cost: $361.2
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# EL PIRU (FRACC)
# #9 Airbnbs found
# Airbnb average cost: $1984.6666666666667
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# EL PIRUL
# #11 Airbnbs found
# Airbnb average cost: $633.0909090909091
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# EL POCITO
# #3 Airbnbs found
# Airbnb average cost: $475.3333333333333
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# EL RODEO
# #2 Airbnbs found
# Airbnb average cost: $575.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# EL RUEDO
# #18 Airbnbs found
# Airbnb average cost: $923.9444444444445
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# EMANCIPACION DEL PUEBLO
# #20 Airbnbs found
# Airbnb average cost: $586.25
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# ESTADO DE HIDALGO
# #7 Airbnbs found
# Airbnb average cost: $672.4285714285714
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# ESTADO DE HIDALGO (AMPL)
# #6 Airbnbs found
# Airbnb average cost: $737.3333333333334
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# ESTADO DE HIDALGO_
# #18 Airbnbs found
# Airbnb average cost: $485.72222222222223
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# FLOR DE MARIA
# #28 Airbnbs found
# Airbnb average cost: $1194.357142857143
# #1 Starbucks found
# -----------------------------------
# -----------------------------------
# FLORIDA
# #87 Airbnbs found
# Airbnb average cost: $1577.9655172413793
# #3 Starbucks found
# -----------------------------------
# -----------------------------------
# FRANCISCO VILLA
# #13 Airbnbs found
# Airbnb average cost: $962.5384615384615
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# GALEANA
# #12 Airbnbs found
# Airbnb average cost: $2899.3333333333335
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# GARCIMARRERO
# #19 Airbnbs found
# Airbnb average cost: $571.3157894736842
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# GARCIMARRERO NORTE
# #16 Airbnbs found
# Airbnb average cost: $478.5625
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# GARCIMARRERO REACOMODO
# #18 Airbnbs found
# Airbnb average cost: $570.5
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# GOLONDRINAS
# #10 Airbnbs found
# Airbnb average cost: $387.7
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# GOLONDRINAS 1RA SECCION
# #2 Airbnbs found
# Airbnb average cost: $363.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# GOLONDRINAS 2DA SECCION
# #15 Airbnbs found
# Airbnb average cost: $1269.2
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# GRAL A ROSALES
# #29 Airbnbs found
# Airbnb average cost: $953.0689655172414
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# GRAL C  A  MADRAZO
# #100 Airbnbs found
# Airbnb average cost: $1513.86
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# GUADALUPE INN
# #79 Airbnbs found
# Airbnb average cost: $1563.26582278481
# #2 Starbucks found
# -----------------------------------
# -----------------------------------
# HACIENDA DE GUADALUPE CHIMALISTAC
# #72 Airbnbs found
# Airbnb average cost: $1103.236111111111
# #2 Starbucks found
# -----------------------------------
# -----------------------------------
# HERON PROAL
# #11 Airbnbs found
# Airbnb average cost: $778.8181818181819
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# HOGAR Y REDENCION
# #20 Airbnbs found
# Airbnb average cost: $503.1
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# ISIDRO FABELA
# #8 Airbnbs found
# Airbnb average cost: $527.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# JALALPA
# #10 Airbnbs found
# Airbnb average cost: $1764.6
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# JALALPA (AMPL)
# #3 Airbnbs found
# Airbnb average cost: $306.6666666666667
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# JALALPA EL GRANDE
# #16 Airbnbs found
# Airbnb average cost: $691.0625
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# JALALPA TEPITO
# #2 Airbnbs found
# Airbnb average cost: $527.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# JARDINES DEL PEDREGAL
# #5 Airbnbs found
# Airbnb average cost: $2214.4
# #2 Starbucks found
# -----------------------------------
# -----------------------------------
# JOSE MARIA PINO SUAREZ
# #21 Airbnbs found
# Airbnb average cost: $769.3333333333334
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# JURISTAS
# #10 Airbnbs found
# Airbnb average cost: $784.7
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LA ANGOSTURA
# #24 Airbnbs found
# Airbnb average cost: $1560.9583333333333
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LA ARAA
# #20 Airbnbs found
# Airbnb average cost: $484.65
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LA CANADA
# #15 Airbnbs found
# Airbnb average cost: $1190.9333333333334
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LA CASCADA
# #34 Airbnbs found
# Airbnb average cost: $920.8235294117648
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LA CEBADA (AMPL)
# #5 Airbnbs found
# Airbnb average cost: $313.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LA CONCHITA
# #10 Airbnbs found
# Airbnb average cost: $718.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LA HERRADURA
# #24 Airbnbs found
# Airbnb average cost: $697.5833333333334
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LA HUERTA
# #11 Airbnbs found
# Airbnb average cost: $570.7272727272727
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LA JOYA
# #4 Airbnbs found
# Airbnb average cost: $409.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LA LOMA
# #17 Airbnbs found
# Airbnb average cost: $1698.2941176470588
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LA MARTINICA
# #9 Airbnbs found
# Airbnb average cost: $1425.4444444444443
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LA MEXICANA
# #5 Airbnbs found
# Airbnb average cost: $361.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LA MEXICANA (AMPL)
# #14 Airbnbs found
# Airbnb average cost: $381.2857142857143
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LA MILAGROSA
# #10 Airbnbs found
# Airbnb average cost: $1265.7
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LA OTRA BANDA
# #81 Airbnbs found
# Airbnb average cost: $1585.6049382716049
# #2 Starbucks found
# -----------------------------------
# -----------------------------------
# LA PALMITA
# #16 Airbnbs found
# Airbnb average cost: $399.6875
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LA PERA XOCHINAHUAC (U HAB)
# #9 Airbnbs found
# Airbnb average cost: $1598.2222222222222
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LA PRESA
# #3 Airbnbs found
# Airbnb average cost: $428.6666666666667
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LA PRESA SECCION HORNOS
# #3 Airbnbs found
# Airbnb average cost: $398.6666666666667
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LADERA GRANDE O LA CEBADITA
# #8 Airbnbs found
# Airbnb average cost: $594.375
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LAS AGUILAS
# #21 Airbnbs found
# Airbnb average cost: $856.2857142857143
# #1 Starbucks found
# -----------------------------------
# -----------------------------------
# LAS AGUILAS (AMPL)
# #14 Airbnbs found
# Airbnb average cost: $1399.5714285714287
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LAS AGUILAS SECC HORNOS
# #22 Airbnbs found
# Airbnb average cost: $786.2272727272727
# #1 Starbucks found
# -----------------------------------
# -----------------------------------
# LAS CUEVITAS
# #16 Airbnbs found
# Airbnb average cost: $399.6875
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LAS PALMAS
# #7 Airbnbs found
# Airbnb average cost: $674.8571428571429
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LIBERACION PROLETARIA
# #8 Airbnbs found
# Airbnb average cost: $347.375
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LIBERALES DE 1857
# #9 Airbnbs found
# Airbnb average cost: $598.8888888888889
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LLANO REDONDO
# #19 Airbnbs found
# Airbnb average cost: $780.1052631578947
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LOMAS DE AXOMIATLA
# #58 Airbnbs found
# Airbnb average cost: $611.051724137931
# #1 Starbucks found
# -----------------------------------
# -----------------------------------
# LOMAS DE BECERRA
# #8 Airbnbs found
# Airbnb average cost: $384.875
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LOMAS DE BECERRA (U HAB)
# #36 Airbnbs found
# Airbnb average cost: $1014.7777777777778
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LOMAS DE BECERRA ARVIDE (U HAB)
# #10 Airbnbs found
# Airbnb average cost: $682.3
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LOMAS DE CAPULA
# #7 Airbnbs found
# Airbnb average cost: $1801.142857142857
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LOMAS DE CAPULIN
# #7 Airbnbs found
# Airbnb average cost: $1094.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LOMAS DE CENTENARIO (U HAB)
# #10 Airbnbs found
# Airbnb average cost: $841.8
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LOMAS DE CHAMONTOYA
# #3 Airbnbs found
# Airbnb average cost: $466.3333333333333
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LOMAS DE GUADALUPE
# #23 Airbnbs found
# Airbnb average cost: $821.7826086956521
# #2 Starbucks found
# -----------------------------------
# -----------------------------------
# LOMAS DE LA ERA
# #3 Airbnbs found
# Airbnb average cost: $382.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LOMAS DE LAS AGUILAS
# #12 Airbnbs found
# Airbnb average cost: $2662.0833333333335
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LOMAS DE LOS ANGELES TETELPAN
# #25 Airbnbs found
# Airbnb average cost: $1150.08
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LOMAS DE LOS CEDROS
# #5 Airbnbs found
# Airbnb average cost: $923.2
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LOMAS DE NUEVO MEXICO
# #9 Airbnbs found
# Airbnb average cost: $496.1111111111111
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LOMAS DE PLATEROS (U HAB) I
# #15 Airbnbs found
# Airbnb average cost: $514.9333333333333
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LOMAS DE PLATEROS (U HAB) II
# #50 Airbnbs found
# Airbnb average cost: $824.54
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LOMAS DE PUERTA GRANDE
# #12 Airbnbs found
# Airbnb average cost: $778.9166666666666
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LOMAS DE SAN ANGEL INN
# #53 Airbnbs found
# Airbnb average cost: $750.6037735849056
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LOMAS DE SANTA FE
# #19 Airbnbs found
# Airbnb average cost: $1073.421052631579
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LOMAS DE SANTA FE II
# #32 Airbnbs found
# Airbnb average cost: $1294.9375
# #6 Starbucks found
# -----------------------------------
# -----------------------------------
# LOMAS DE SANTO DOMINGO
# #16 Airbnbs found
# Airbnb average cost: $1076.5
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LOMAS DE SANTO DOMINGO (AMPL)
# #11 Airbnbs found
# Airbnb average cost: $765.4545454545455
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LOMAS DE TARANGO
# #15 Airbnbs found
# Airbnb average cost: $1157.3333333333333
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LOMAS DE TETELPAN
# #24 Airbnbs found
# Airbnb average cost: $1225.75
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LORETO
# #108 Airbnbs found
# Airbnb average cost: $1261.2222222222222
# #2 Starbucks found
# -----------------------------------
# -----------------------------------
# LOS CEDROS
# #21 Airbnbs found
# Airbnb average cost: $502.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LOS GAMITOS
# #10 Airbnbs found
# Airbnb average cost: $567.8
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# MARGARITA M DE JUAREZ
# #10 Airbnbs found
# Airbnb average cost: $959.5
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# MARIA G DE GARCIA RUIZ
# #7 Airbnbs found
# Airbnb average cost: $556.5714285714286
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# MARTIRES DE TACUBAYA
# #6 Airbnbs found
# Airbnb average cost: $399.3333333333333
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# MERCED GOMEZ
# #29 Airbnbs found
# Airbnb average cost: $653.9310344827586
# #1 Starbucks found
# -----------------------------------
# -----------------------------------
# METROPOLITANO (U HAB)
# #10 Airbnbs found
# Airbnb average cost: $1463.4
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# MIGUEL GAONA ARMENTA
# #40 Airbnbs found
# Airbnb average cost: $717.625
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# MIGUEL HIDALGO
# #32 Airbnbs found
# Airbnb average cost: $16234.21875
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# MILPA DEL CEDRO
# #35 Airbnbs found
# Airbnb average cost: $831.3142857142857
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# MINAS DE CRISTO
# #21 Airbnbs found
# Airbnb average cost: $971.4761904761905
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# MOLINO DE ROSAS
# #32 Airbnbs found
# Airbnb average cost: $910.25
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# MOLINO DE ROSAS (AMPL)
# #25 Airbnbs found
# Airbnb average cost: $909.92
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# MOLINO DE SANTO DOMINGO
# #9 Airbnbs found
# Airbnb average cost: $736.6666666666666
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# MOLINO DE SANTO DOMINGO (U HAB)
# #9 Airbnbs found
# Airbnb average cost: $736.6666666666666
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# OCHO DE AGOSTO
# #142 Airbnbs found
# Airbnb average cost: $814.7887323943662
# #3 Starbucks found
# -----------------------------------
# -----------------------------------
# OCOTILLOS
# #31 Airbnbs found
# Airbnb average cost: $1450.967741935484
# #1 Starbucks found
# -----------------------------------
# -----------------------------------
# OLIVAR DE LOS PADRES
# #20 Airbnbs found
# Airbnb average cost: $1683.3
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# OLIVAR DEL CONDE 1RA SECCION I
# #5 Airbnbs found
# Airbnb average cost: $387.8
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# OLIVAR DEL CONDE 1RA SECCION II
# #14 Airbnbs found
# Airbnb average cost: $335.7857142857143
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# OLIVAR DEL CONDE 2DA SECCION I
# #18 Airbnbs found
# Airbnb average cost: $522.0555555555555
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# OLIVAR DEL CONDE 2DA SECCION II
# #22 Airbnbs found
# Airbnb average cost: $1769.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# PALMAS
# #11 Airbnbs found
# Airbnb average cost: $364.72727272727275
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# PALMAS AXOTITLA
# #12 Airbnbs found
# Airbnb average cost: $1125.5833333333333
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# PARAJE EL CABALLITO
# #1 Airbnbs found
# Airbnb average cost: $259.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# PARQUE RESIDENCIAL SAN ANTONIO (U HAB)
# #119 Airbnbs found
# Airbnb average cost: $888.5714285714286
# #3 Starbucks found
# -----------------------------------
# -----------------------------------
# PASEO DE LAS LOMAS-SAN GABRIEL
# #57 Airbnbs found
# Airbnb average cost: $1328.1052631578948
# #6 Starbucks found
# -----------------------------------
# -----------------------------------
# PILOTO (ADOLFO LOPEZ MATEOS)
# #10 Airbnbs found
# Airbnb average cost: $2216.6
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# PILOTO (ADOLFO LOPEZ MATEOS) (AMPL)
# #14 Airbnbs found
# Airbnb average cost: $2666.3571428571427
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# PODER POPULAR
# #21 Airbnbs found
# Airbnb average cost: $778.2380952380952
# #1 Starbucks found
# -----------------------------------
# -----------------------------------
# POLVORA
# #9 Airbnbs found
# Airbnb average cost: $774.4444444444445
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# PONCIANO ARRIAGA
# #10 Airbnbs found
# Airbnb average cost: $952.4
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# PRADOS LA PROVIDENCIA
# #11 Airbnbs found
# Airbnb average cost: $696.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# PREDIO LA ANGOSTURA
# #9 Airbnbs found
# Airbnb average cost: $949.6666666666666
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# PRESIDENTES
# #6 Airbnbs found
# Airbnb average cost: $2772.6666666666665
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# PRESIDENTES 1RA (AMPL)
# #6 Airbnbs found
# Airbnb average cost: $2790.1666666666665
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# PRESIDENTES 2DA (AMPL)
# #10 Airbnbs found
# Airbnb average cost: $3438.1
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# PRIVADA CENTENARIO
# #13 Airbnbs found
# Airbnb average cost: $860.4615384615385
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# PROF JOSE ARTURO LOPEZ
# #10 Airbnbs found
# Airbnb average cost: $1415.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# PROGRESO TIZAPAN
# #64 Airbnbs found
# Airbnb average cost: $1503.625
# #2 Starbucks found
# -----------------------------------
# -----------------------------------
# PUEBLO NUEVO
# #14 Airbnbs found
# Airbnb average cost: $854.5714285714286
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# PUENTE COLORADO
# #17 Airbnbs found
# Airbnb average cost: $850.2941176470588
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# PUENTE COLORADO (AMPL)
# #20 Airbnbs found
# Airbnb average cost: $827.35
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# PUNTA DE CEHUAYO
# #22 Airbnbs found
# Airbnb average cost: $553.9545454545455
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# REACOMODO EL CUERNITO
# #4 Airbnbs found
# Airbnb average cost: $436.5
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# REACOMODO PINO SUAREZ
# #10 Airbnbs found
# Airbnb average cost: $696.7
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# REAL DEL MONTE
# #13 Airbnbs found
# Airbnb average cost: $1120.6153846153845
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# RESIDENCIAL MARIA ISABEL
# #20 Airbnbs found
# Airbnb average cost: $786.45
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# RINCON DE LA BOLSA
# #8 Airbnbs found
# Airbnb average cost: $1025.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SAN ANGEL
# #106 Airbnbs found
# Airbnb average cost: $1399.1603773584907
# #4 Starbucks found
# -----------------------------------
# -----------------------------------
# SAN ANGEL INN
# #69 Airbnbs found
# Airbnb average cost: $1469.1159420289855
# #1 Starbucks found
# -----------------------------------
# -----------------------------------
# SAN BARTOLO AMEYALCO (PBLO)
# #13 Airbnbs found
# Airbnb average cost: $827.1538461538462
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SAN CLEMENTE
# #18 Airbnbs found
# Airbnb average cost: $610.5555555555555
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SAN GABRIEL
# #102 Airbnbs found
# Airbnb average cost: $1485.6666666666667
# #1 Starbucks found
# -----------------------------------
# -----------------------------------
# SAN PEDRO DE LOS PINOS
# #156 Airbnbs found
# Airbnb average cost: $890.7435897435897
# #3 Starbucks found
# -----------------------------------
# -----------------------------------
# SANTA FE
# #18 Airbnbs found
# Airbnb average cost: $935.8888888888889
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SANTA FE (U HAB)
# #9 Airbnbs found
# Airbnb average cost: $754.4444444444445
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SANTA FE KM 8.5
# #57 Airbnbs found
# Airbnb average cost: $1456.438596491228
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SANTA LUCIA
# #20 Airbnbs found
# Airbnb average cost: $843.3
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SANTA LUCIA (PBLO)
# #18 Airbnbs found
# Airbnb average cost: $781.4444444444445
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SANTA LUCIA REACOMODO
# #19 Airbnbs found
# Airbnb average cost: $756.1052631578947
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SANTA MARIA NONOALCO
# #111 Airbnbs found
# Airbnb average cost: $787.990990990991
# #1 Starbucks found
# -----------------------------------
# -----------------------------------
# SANTA ROSA XOCHIAC (PBLO)
# #6 Airbnbs found
# Airbnb average cost: $848.3333333333334
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SEARS ROEBUCK (U HAB)
# #34 Airbnbs found
# Airbnb average cost: $853.7352941176471
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# TARANGO (U HAB)
# #9 Airbnbs found
# Airbnb average cost: $1425.4444444444443
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# TECOLALCO
# #8 Airbnbs found
# Airbnb average cost: $563.125
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# TEJOCOTE
# #10 Airbnbs found
# Airbnb average cost: $1341.1
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# TEPEACA
# #13 Airbnbs found
# Airbnb average cost: $734.3076923076923
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# TEPEACA (AMPL)
# #19 Airbnbs found
# Airbnb average cost: $717.5263157894736
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# TEPOPOTLA
# #21 Airbnbs found
# Airbnb average cost: $650.8095238095239
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# TETELPAN
# #19 Airbnbs found
# Airbnb average cost: $1721.5263157894738
# #1 Starbucks found
# -----------------------------------
# -----------------------------------
# TETELPAN (PBLO)
# #22 Airbnbs found
# Airbnb average cost: $672.4545454545455
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# TETLALPAN
# #24 Airbnbs found
# Airbnb average cost: $728.5
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# TIZAMPAMPANO
# #28 Airbnbs found
# Airbnb average cost: $1075.357142857143
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# TIZAPAN_TIZAPAN SAN ANGEL
# #81 Airbnbs found
# Airbnb average cost: $1385.0123456790122
# #3 Starbucks found
# -----------------------------------
# -----------------------------------
# TLACOPAC
# #72 Airbnbs found
# Airbnb average cost: $1520.361111111111
# #2 Starbucks found
# -----------------------------------
# -----------------------------------
# TLACOYAQUE
# #3 Airbnbs found
# Airbnb average cost: $382.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# TLACOYAQUE (AMPL)
# #4 Airbnbs found
# Airbnb average cost: $436.5
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# TLACOYAQUE (BARR)
# #6 Airbnbs found
# Airbnb average cost: $477.6666666666667
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# TLACUITLAPA
# #19 Airbnbs found
# Airbnb average cost: $704.2631578947369
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# TLACUITLAPA 2DO REACOMODO (AMPL)
# #11 Airbnbs found
# Airbnb average cost: $1170.7272727272727
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# TLAPECHICO
# #12 Airbnbs found
# Airbnb average cost: $839.8333333333334
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# TOLTECA
# #59 Airbnbs found
# Airbnb average cost: $849.5593220338983
# #3 Starbucks found
# -----------------------------------
# -----------------------------------
# TORRES DE MIXCOAC (U HAB)
# #88 Airbnbs found
# Airbnb average cost: $902.0227272727273
# #1 Starbucks found
# -----------------------------------
# -----------------------------------
# TORRES DE POTRERO
# #6 Airbnbs found
# Airbnb average cost: $1750.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# TORRES SAN ANTONIO (U HAB)
# #95 Airbnbs found
# Airbnb average cost: $860.4947368421052
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# TORRES SAN PEDRO (U HAB)
# #109 Airbnbs found
# Airbnb average cost: $912.4495412844037
# #3 Starbucks found
# -----------------------------------
# -----------------------------------
# UNIDAD POPULAR TEPEACA
# #19 Airbnbs found
# Airbnb average cost: $586.0526315789474
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# UNION OLIVOS
# #10 Airbnbs found
# Airbnb average cost: $814.5
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# UNION POPULAR EMILIANO ZAPATA (U HAB)
# #21 Airbnbs found
# Airbnb average cost: $436.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# VALENTIN GOMEZ FARIAS
# #13 Airbnbs found
# Airbnb average cost: $732.0769230769231
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# VILLA PROGRESISTA
# #18 Airbnbs found
# Airbnb average cost: $707.0555555555555
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# VILLA SOLIDARIDAD
# #14 Airbnbs found
# Airbnb average cost: $1079.857142857143
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# VILLA VERDUN
# #42 Airbnbs found
# Airbnb average cost: $547.8095238095239
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# ZENON DELGADO
# #8 Airbnbs found
# Airbnb average cost: $439.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# ZOTOLTITLA
# #10 Airbnbs found
# Airbnb average cost: $1285.8
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# AGUILERA
# #25 Airbnbs found
# Airbnb average cost: $761.12
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# ALDANA
# #22 Airbnbs found
# Airbnb average cost: $857.7727272727273
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# AMPLIACION PETROLERA
# #35 Airbnbs found
# Airbnb average cost: $454.77142857142854
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# ANGEL ZIMBRON
# #24 Airbnbs found
# Airbnb average cost: $762.125
# #1 Starbucks found
# -----------------------------------
# -----------------------------------
# ARENAL
# #106 Airbnbs found
# Airbnb average cost: $561.8207547169811
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# CENTRO DE AZCAPOTZALCO
# #34 Airbnbs found
# Airbnb average cost: $466.47058823529414
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# CLAVERIA
# #36 Airbnbs found
# Airbnb average cost: $579.5
# #1 Starbucks found
# -----------------------------------
# -----------------------------------
# COLTONGO
# #13 Airbnbs found
# Airbnb average cost: $951.2307692307693
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# COSMOPOLITA
# #16 Airbnbs found
# Airbnb average cost: $674.375
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# COSMOPOLITA (AMPL)
# #21 Airbnbs found
# Airbnb average cost: $705.2380952380952
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# CRUZ ROJA TEPANTONGO (U HAB)
# #3 Airbnbs found
# Airbnb average cost: $416.3333333333333
# #1 Starbucks found
# -----------------------------------
# -----------------------------------
# CUITLHUAC 1 Y 2 (U HAB)
# #21 Airbnbs found
# Airbnb average cost: $750.047619047619
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# CUITLHUAC 3 Y 4 (U HAB)
# #23 Airbnbs found
# Airbnb average cost: $573.0869565217391
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# DEL GAS
# #50 Airbnbs found
# Airbnb average cost: $1010.28
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# DEL GAS (AMPL)
# #55 Airbnbs found
# Airbnb average cost: $995.5272727272727
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# DEL MAESTRO
# #16 Airbnbs found
# Airbnb average cost: $441.75
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# DEL RECREO
# #26 Airbnbs found
# Airbnb average cost: $586.1153846153846
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# DEMET (U HAB)
# #7 Airbnbs found
# Airbnb average cost: $334.42857142857144
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# ECOLOGICA NOVEDADES IMPACTO (U HAB)
# #1 Airbnbs found
# Airbnb average cost: $520.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# EL JAGUEY-ESTACION PANTACO
# #7 Airbnbs found
# Airbnb average cost: $677.7142857142857
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# EL ROSARIO A (U HAB)
# #2 Airbnbs found
# Airbnb average cost: $550.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# EL ROSARIO B (U HAB)
# #3 Airbnbs found
# Airbnb average cost: $617.6666666666666
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# EL ROSARIO C (U HAB)
# #3 Airbnbs found
# Airbnb average cost: $453.3333333333333
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# EUZKADI
# #11 Airbnbs found
# Airbnb average cost: $624.5454545454545
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# EX-HACIENDA EL ROSARIO
# #5 Airbnbs found
# Airbnb average cost: $249.4
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# FERRERIA
# #3 Airbnbs found
# Airbnb average cost: $291.3333333333333
# #1 Starbucks found
# -----------------------------------
# -----------------------------------
# FERRERIA (U HAB)
# #3 Airbnbs found
# Airbnb average cost: $291.3333333333333
# #1 Starbucks found
# -----------------------------------
# -----------------------------------
# FRANCISCO VILLA (U HAB)
# #9 Airbnbs found
# Airbnb average cost: $426.22222222222223
# #1 Starbucks found
# -----------------------------------
# -----------------------------------
# FUENTES DE AZCAPOTZALCO-PARQUES DE AZCAPOTZALCO (U HAB)
# #33 Airbnbs found
# Airbnb average cost: $574.8787878787879
# #1 Starbucks found
# -----------------------------------
# -----------------------------------
# HOGAR Y SEGURIDAD/NUEVA SANTA MARIA
# #32 Airbnbs found
# Airbnb average cost: $746.3125
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# HOGARES FERROCARRILEROS (U HAB)
# #16 Airbnbs found
# Airbnb average cost: $730.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# HUAUTLA DE LAS SALINAS (BARR)
# #1 Airbnbs found
# Airbnb average cost: $950.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# IGNACIO ALLENDE
# #63 Airbnbs found
# Airbnb average cost: $991.7619047619048
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# INDUSTRIAL VALLEJO (U HAB)
# #0 Airbnbs found
# Airbnb average cost: $0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# ISSFAM LAS ARMAS (U HAB)
# #4 Airbnbs found
# Airbnb average cost: $449.75
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# JARDIN AZPEITIA
# #17 Airbnbs found
# Airbnb average cost: $566.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# JARDINES CEYLAN (U HAB)
# #1 Airbnbs found
# Airbnb average cost: $300.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LA PRECIOSA
# #23 Airbnbs found
# Airbnb average cost: $503.30434782608694
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LA RAZA
# #109 Airbnbs found
# Airbnb average cost: $364.08256880733944
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LAS SALINAS
# #1 Airbnbs found
# Airbnb average cost: $876.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LIBERACION
# #40 Airbnbs found
# Airbnb average cost: $887.475
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LIBERTAD
# #11 Airbnbs found
# Airbnb average cost: $680.8181818181819
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LOS REYES (BARR)
# #12 Airbnbs found
# Airbnb average cost: $384.6666666666667
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# MANUEL RIVERA ANAYA CROC I (U HAB)
# #1 Airbnbs found
# Airbnb average cost: $753.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# MIGUEL HIDALGO (U HAB)
# #17 Airbnbs found
# Airbnb average cost: $561.7058823529412
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# MONTE ALTO
# #5 Airbnbs found
# Airbnb average cost: $700.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# NEXTENGO (BARR)
# #32 Airbnbs found
# Airbnb average cost: $555.96875
# #1 Starbucks found
# -----------------------------------
# -----------------------------------
# NUEVA EL ROSARIO
# #5 Airbnbs found
# Airbnb average cost: $399.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# NUEVA ESPAA
# #6 Airbnbs found
# Airbnb average cost: $454.1666666666667
# ...
# #5 Airbnbs found
# Airbnb average cost: $461.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# FEDERAL
# #57 Airbnbs found
# Airbnb average cost: $737.8947368421053
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# IGNACIO ZARAGOZA I
# #37 Airbnbs found
# Airbnb average cost: $1325.2702702702702
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# JARDIN BALBUENA I
# #55 Airbnbs found
# Airbnb average cost: $859.0909090909091
# #1 Starbucks found
# -----------------------------------
# -----------------------------------
# MAGDALENA  MIXHUCA (PBLO)
# #32 Airbnbs found
# Airbnb average cost: $1091.5625
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# MOCTEZUMA 2A SECCION III
# #57 Airbnbs found
# Airbnb average cost: $588.3157894736842
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# PINO (U HAB)
# #18 Airbnbs found
# Airbnb average cost: $1186.6666666666667
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# BAHIA (U HAB)
# #65 Airbnbs found
# Airbnb average cost: $666.6615384615385
# #7 Starbucks found
# -----------------------------------
# -----------------------------------
# MORELOS II
# #13 Airbnbs found
# Airbnb average cost: $555.1538461538462
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# JARDIN BALBUENA II
# #44 Airbnbs found
# Airbnb average cost: $1191.2272727272727
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# VIADUCTO  - BALBUENA )CONJ HAB)
# #21 Airbnbs found
# Airbnb average cost: $925.7142857142857
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# EMILIANO ZAPATA (U HAB)
# #15 Airbnbs found
# Airbnb average cost: $651.4
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LORENZO BOTURINI
# #32 Airbnbs found
# Airbnb average cost: $1260.9375
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# ADOLFO LOPEZ MATEOS
# #19 Airbnbs found
# Airbnb average cost: $1052.6842105263158
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# AERONAUTICA MILITAR
# #37 Airbnbs found
# Airbnb average cost: $1317.7567567567567
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# 24 DE ABRIL
# #37 Airbnbs found
# Airbnb average cost: $1154.7837837837837
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# EL PARQUE
# #38 Airbnbs found
# Airbnb average cost: $1152.078947368421
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# ALVARO OBREGON
# #35 Airbnbs found
# Airbnb average cost: $1003.5142857142857
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# JARDIN BALBUENA III
# #37 Airbnbs found
# Airbnb average cost: $794.8648648648649
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# KENNEDY (U HAB)
# #48 Airbnbs found
# Airbnb average cost: $1104.5208333333333
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# PUEBLA
# #46 Airbnbs found
# Airbnb average cost: $708.3913043478261
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# AMPL CARACOL
# #5 Airbnbs found
# Airbnb average cost: $356.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# ALTOS TEPETLICA
# #0 Airbnbs found
# Airbnb average cost: $0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SAN BARTOLO EL CHICO
# #31 Airbnbs found
# Airbnb average cost: $794.516129032258
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SAN JOSE LAS PERITAS
# #13 Airbnbs found
# Airbnb average cost: $609.3846153846154
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SAN JUAN TEPEPAN
# #15 Airbnbs found
# Airbnb average cost: $991.1333333333333
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LA CEBADA
# #20 Airbnbs found
# Airbnb average cost: $1005.85
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SAN LORENZO LA CEBADA I
# #19 Airbnbs found
# Airbnb average cost: $667.4736842105264
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# HUICHAPAN
# #7 Airbnbs found
# Airbnb average cost: $2229.4285714285716
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# INFONAVIT PROLONGACION DIVISION DEL NORTE (U HAB)
# #6 Airbnbs found
# Airbnb average cost: $632.3333333333334
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LA NORIA
# #4 Airbnbs found
# Airbnb average cost: $424.75
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# TIERRA NUEVA
# #6 Airbnbs found
# Airbnb average cost: $449.3333333333333
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# PASEOS DEL SUR
# #17 Airbnbs found
# Airbnb average cost: $583.0588235294117
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# VILLA XOCHIMILCO (U HAB)
# #5 Airbnbs found
# Airbnb average cost: $648.6
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LA GUADALUPITA (BARR)
# #7 Airbnbs found
# Airbnb average cost: $787.2857142857143
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SAN DIEGO (BARR)
# #7 Airbnbs found
# Airbnb average cost: $787.2857142857143
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SANTA CRUCITA (BARR)
# #6 Airbnbs found
# Airbnb average cost: $860.1666666666666
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# BELEM (BARR)
# #7 Airbnbs found
# Airbnb average cost: $1008.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# EL ROSARIO (BARR)
# #6 Airbnbs found
# Airbnb average cost: $860.1666666666666
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# JARDINES DEL SUR
# #9 Airbnbs found
# Airbnb average cost: $1984.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SAN ANTONIO (BARR)
# #7 Airbnbs found
# Airbnb average cost: $808.7142857142857
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SAN CRISTOBAL (BARR)
# #7 Airbnbs found
# Airbnb average cost: $1008.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SAN JUAN (BARR)
# #4 Airbnbs found
# Airbnb average cost: $712.5
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SAN LORENZO LA CEBADA II
# #17 Airbnbs found
# Airbnb average cost: $559.2941176470588
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SAN PEDRO (BARR)
# #7 Airbnbs found
# Airbnb average cost: $2294.4285714285716
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# BOSQUE RESIDENCIAL DEL SUR (FRACC)
# #26 Airbnbs found
# Airbnb average cost: $839.3461538461538
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LA CONCEPCION TLACOAPA (BARR)
# #1 Airbnbs found
# Airbnb average cost: $900.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LA CONCHA
# #5 Airbnbs found
# Airbnb average cost: $3151.2
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# CANAL ONCE (U HAB)
# #0 Airbnbs found
# Airbnb average cost: $0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LORETO PEA POBRE (U HAB)
# #1 Airbnbs found
# Airbnb average cost: $224.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# POTRERO DE SAN BERNARDINO
# #8 Airbnbs found
# Airbnb average cost: $671.5
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SANTA MARIA TEPEPAN (PBLO)
# #29 Airbnbs found
# Airbnb average cost: $550.8965517241379
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# TESMIC (RDCIAL)
# #4 Airbnbs found
# Airbnb average cost: $3229.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SAN ESTEBAN (BARR)
# #4 Airbnbs found
# Airbnb average cost: $740.25
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# XALTOCAN (BARR)
# #8 Airbnbs found
# Airbnb average cost: $2378.5
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# JOYA DE VARGAS
# #2 Airbnbs found
# Airbnb average cost: $391.5
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LA SANTISIMA (BARR)
# #2 Airbnbs found
# Airbnb average cost: $375.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# NUEVA TENOCHTITLAN
# #1 Airbnbs found
# Airbnb average cost: $320.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SANTA CRUZ XOCHITEPEC (PBLO)
# #12 Airbnbs found
# Airbnb average cost: $671.3333333333334
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# TLAXOPAN
# #1 Airbnbs found
# Airbnb average cost: $500.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# XICALHUACAN
# #3 Airbnbs found
# Airbnb average cost: $393.3333333333333
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# RINCONADA DEL SUR (U HAB)
# #9 Airbnbs found
# Airbnb average cost: $1961.3333333333333
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# AZTLAN-APACHES (U HAB)
# #8 Airbnbs found
# Airbnb average cost: $4018.125
# #1 Starbucks found
# -----------------------------------
# -----------------------------------
# BARRIO 18
# #6 Airbnbs found
# Airbnb average cost: $570.5
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# CALTONGO (BARR)
# #0 Airbnbs found
# Airbnb average cost: $0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LA ASUNCION (BARR)
# #2 Airbnbs found
# Airbnb average cost: $625.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SAN LORENZO (BARR)
# #2 Airbnbs found
# Airbnb average cost: $375.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SAN MARCOS (AMPL)
# #3 Airbnbs found
# Airbnb average cost: $621.3333333333334
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# TEPEPAN (AMPL)
# #14 Airbnbs found
# Airbnb average cost: $685.8571428571429
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# TECACALANCO
# #2 Airbnbs found
# Airbnb average cost: $700.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LA NORIA TEPEPAN
# #11 Airbnbs found
# Airbnb average cost: $539.7272727272727
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SAN MARCOS (BARR)
# #5 Airbnbs found
# Airbnb average cost: $2650.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SAN GREGORIO ATLAPULCO (PBLO)
# #1 Airbnbs found
# Airbnb average cost: $617.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SANTA CRUZ ACALPIXCA (PBLO)
# #0 Airbnbs found
# Airbnb average cost: $0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SAN LORENZO ATEMOAYA (PBLO)
# #10 Airbnbs found
# Airbnb average cost: $2537.3
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LOS CERRILLOS III
# #1 Airbnbs found
# Airbnb average cost: $1390.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SAN FRANCISCO CHIQUIMOLA
# #1 Airbnbs found
# Airbnb average cost: $1390.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# EL CARMEN
# #1 Airbnbs found
# Airbnb average cost: $1390.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SAN LORENZO
# #25 Airbnbs found
# Airbnb average cost: $862.24
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SANTA MARIA NATIVITAS (PBLO)
# #10 Airbnbs found
# Airbnb average cost: $1504.1
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SANTIAGO TULYEHUALCO (PBLO)
# #0 Airbnbs found
# Airbnb average cost: $0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# CRISTO REY
# #1 Airbnbs found
# Airbnb average cost: $1390.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# NATIVITAS
# #0 Airbnbs found
# Airbnb average cost: $0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# NATIVITAS (U HAB)
# #4 Airbnbs found
# Airbnb average cost: $3229.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LOS CERRILLOS II
# #0 Airbnbs found
# Airbnb average cost: $0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# OLIVAR SANTA MARIA
# #0 Airbnbs found
# Airbnb average cost: $0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# CERRO GRANDE
# #0 Airbnbs found
# Airbnb average cost: $0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# LA CAADA
# #0 Airbnbs found
# Airbnb average cost: $0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SANTIAGO TEPALCATLALPAN (PBLO)
# #2 Airbnbs found
# Airbnb average cost: $1024.5
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SAN JOSE ZACATEPEC
# #1 Airbnbs found
# Airbnb average cost: $3000.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SANTA CRUZ CHAVARRIETA
# #1 Airbnbs found
# Airbnb average cost: $3000.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SANTA INES
# #0 Airbnbs found
# Airbnb average cost: $0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SAN MATEO XALPA (PBLO)
# #1 Airbnbs found
# Airbnb average cost: $3000.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SAN ANDRES AHUAYUCAN (PBLO)
# #1 Airbnbs found
# Airbnb average cost: $480.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SAN LUCAS XOCHIMANCA (PBLO)
# #0 Airbnbs found
# Airbnb average cost: $0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# GUADALUPE
# #0 Airbnbs found
# Airbnb average cost: $0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# NATIVITAS LA JOYA (AMPL)
# #2 Airbnbs found
# Airbnb average cost: $391.5
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SAN FRANCISCO TLALNEPANTLA (PBLO)
# #0 Airbnbs found
# Airbnb average cost: $0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SANTA CECILIA TEPETLAPA (PBLO)
# #2 Airbnbs found
# Airbnb average cost: $5009.0
# #0 Starbucks found
# -----------------------------------
# -----------------------------------
# SAN LUIS TLAXIALTEMALCO (PBLO)
# #1 Airbnbs found
# Airbnb average cost: $453.0
# #0 Starbucks found
# -----------------------------------

# %%
catastro_df.to_csv('catastro_ml_model_radio700.csv', index = False)

# %%
catastro_df_ml['flag_airbnb'] = ''
catastro_df_ml['flag_starbucks'] = ''

for index, row in catastro_df_ml.iterrows():
    is_there_airbnb = row ['no_airbnb']
    is_there_starbucks = row['no_starbucks']
    
    if is_there_airbnb > 0:
        catastro_df.loc[index, 'flag_airbnb'] = 1
    else:
        catastro_df.loc[index, 'flag_airbnb'] = 0
        
    if is_there_starbucks > 0:
        catastro_df.loc[index, 'flag_starbucks'] = 1
    else:
        catastro_df.loc[index, 'flag_starbucks'] = 0

# %%
# Drop unneccesary "Unnamed" column
catastro_df_ml = catastro_df_ml.drop('Unnamed: 0', axis = 1)
catastro_df_ml = catastro_df_ml.drop('index', axis = 1)

# Write Catastro Final DataFrame to csv to store the dat
#catastro_df_ml.to_csv('catastro_ml_model.csv', index = False)

# %%
catastro_df_ml.head()
# Out:
#                      nombre_col  num_code  prom_valor_unitario_suelo  \
# 0                    19 DE MAYO      1210                1404.400000
# 1                  1RA VICTORIA      1150                2061.619503
# 2  1RA VICTORIA SECCION BOSQUES      1150                1788.360000
# 3    2DA  JALALPA TEPITO (AMPL)      1260                1063.626266
# 4           2DA EL PIRUL (AMPL)      1210                1320.710000
#
#      latitud   longitud        alcaldia estado  no_airbnb  no_starbucks  \
# 0  19.361649 -99.253530  Álvaro Obregón   CDMX         19             0
# 1  19.386686 -99.201985  Álvaro Obregón   CDMX         29             0
# 2  19.387826 -99.197446  Álvaro Obregón   CDMX         74             0
# 3  19.375080 -99.233736  Álvaro Obregón   CDMX          3             0
# 4  19.379745 -99.242231  Álvaro Obregón   CDMX         11             0
#
#    airbnb_mean_price flag_airbnb flag_starbucks
# 0         756.684211
# 1        1033.310345
# 2         944.648649
# 3         506.333333
# 4         878.545455

# %%
catastro_df_ml['no_airbnb'] = pd.to_numeric(catastro_df_ml['no_airbnb'], downcast="integer")
catastro_df_ml['no_starbucks'] = pd.to_numeric(catastro_df_ml['no_starbucks'], downcast="integer")
catastro_df_ml['airbnb_mean_price'] = pd.to_numeric(catastro_df_ml['airbnb_mean_price'], downcast="integer")
catastro_df_ml['flag_airbnb'] = pd.to_numeric(catastro_df_ml['flag_airbnb'], downcast="integer")
catastro_df_ml['flag_starbucks'] = pd.to_numeric(catastro_df_ml['flag_starbucks'], downcast="integer")

catastro_df_ml['airbnb_mean_price'] = catastro_df_ml['airbnb_mean_price'].fillna(0)

# %% [markdown]
# # Generate Multiple Regression Model

# %%
# Read processed csv file
catastro_df_ml = pd.read_csv('catastro_ml_model.csv')
catastro_df_ml = catastro_df_ml.fillna(0)
catastro_df_ml
# Out:
#                              nombre_col  num_code  prom_valor_unitario_suelo  \
# 0                            19 DE MAYO      1210                1404.400000
# 1                          1RA VICTORIA      1150                2061.619503
# 2          1RA VICTORIA SECCION BOSQUES      1150                1788.360000
# 3            2DA  JALALPA TEPITO (AMPL)      1260                1063.626266
# 4                   2DA EL PIRUL (AMPL)      1210                1320.710000
# ...                                 ...       ...                        ...
# 1784                          GUADALUPE     16900                 420.703636
# 1785           NATIVITAS LA JOYA (AMPL)     16900                 711.580672
# 1786  SAN FRANCISCO TLALNEPANTLA (PBLO)     16910                 338.647387
# 1787     SANTA CECILIA TEPETLAPA (PBLO)     16880                 534.238763
# 1788     SAN LUIS TLAXIALTEMALCO (PBLO)     16610                 667.526340
#
#         latitud   longitud        alcaldia estado  no_airbnb  no_starbucks  \
# 0     19.361649 -99.253530  Álvaro Obregón   CDMX         19             6
# 1     19.386686 -99.201985  Álvaro Obregón   CDMX         29             0
# 2     19.387826 -99.197446  Álvaro Obregón   CDMX         74             4
# 3     19.375080 -99.233736  Álvaro Obregón   CDMX          3             0
# 4     19.379745 -99.242231  Álvaro Obregón   CDMX         11             0
# ...         ...        ...             ...    ...        ...           ...
# 1784  19.218264 -99.120799      Xochimilco   CDMX          0             0
# 1785  19.237250 -99.093782      Xochimilco   CDMX          2             0
# 1786  19.197937 -99.122385      Xochimilco   CDMX          0             0
# 1787  19.217187 -99.099325      Xochimilco   CDMX          2             0
# 1788  19.256973 -99.035680      Xochimilco   CDMX          1             0
#
#       airbnb_mean_price  flag_airbnb  flag_starbucks
# 0            756.684211            1               1
# 1           1033.310345            1               0
# 2            944.648649            1               1
# 3            506.333333            1               0
# 4            878.545455            1               0
# ...                 ...          ...             ...
# 1784           0.000000            0               0
# 1785         391.500000            1               0
# 1786           0.000000            0               0
# 1787        5009.000000            1               0
# 1788         453.000000            1               0
#
# [1789 rows x 12 columns]

# %%
# Enconde categorical columns
le = LabelEncoder()
catastro_encode = catastro_df_ml.copy()
catastro_encode['alcaldia'] = le.fit_transform(catastro_encode['alcaldia'])

# %%
# Declare independent variables

X = catastro_encode[['no_starbucks','no_airbnb','alcaldia','airbnb_mean_price']]

# Declare depedant variable to predict
y = catastro_encode['prom_valor_unitario_suelo']

# Split dataset into train and test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3)

# Create model
model = LinearRegression()

# Fit Model
model.fit(X_train, y_train)

# Generate predictions
y_pred = model.predict(X_test)


# Generate r squared score
#r_squared = model.score(X_train, y_pred)

# Asses accuracy of the model
print('Mean Square Error: ', mean_squared_error(y_test,y_pred))
print('Mean Absolute Error:', mean_absolute_error(y_test,y_pred))
#print('R squared:', r_squared)
# Out:
# Mean Square Error:  2594764.41209991
# Mean Absolute Error: 1068.1585560134279

# %%
y_pred_total = model.predict(X)

# %%
catastro_df_ml['valor_unitario_pred'] = y_pred_total.tolist()

# %%
catastro_df_ml
# Out:
#                              nombre_col  num_code  prom_valor_unitario_suelo  \
# 0                            19 DE MAYO      1210                1404.400000
# 1                          1RA VICTORIA      1150                2061.619503
# 2          1RA VICTORIA SECCION BOSQUES      1150                1788.360000
# 3            2DA  JALALPA TEPITO (AMPL)      1260                1063.626266
# 4                   2DA EL PIRUL (AMPL)      1210                1320.710000
# ...                                 ...       ...                        ...
# 1784                          GUADALUPE     16900                 420.703636
# 1785           NATIVITAS LA JOYA (AMPL)     16900                 711.580672
# 1786  SAN FRANCISCO TLALNEPANTLA (PBLO)     16910                 338.647387
# 1787     SANTA CECILIA TEPETLAPA (PBLO)     16880                 534.238763
# 1788     SAN LUIS TLAXIALTEMALCO (PBLO)     16610                 667.526340
#
#         latitud   longitud        alcaldia estado  no_airbnb  no_starbucks  \
# 0     19.361649 -99.253530  Álvaro Obregón   CDMX         19             6
# 1     19.386686 -99.201985  Álvaro Obregón   CDMX         29             0
# 2     19.387826 -99.197446  Álvaro Obregón   CDMX         74             4
# 3     19.375080 -99.233736  Álvaro Obregón   CDMX          3             0
# 4     19.379745 -99.242231  Álvaro Obregón   CDMX         11             0
# ...         ...        ...             ...    ...        ...           ...
# 1784  19.218264 -99.120799      Xochimilco   CDMX          0             0
# 1785  19.237250 -99.093782      Xochimilco   CDMX          2             0
# 1786  19.197937 -99.122385      Xochimilco   CDMX          0             0
# 1787  19.217187 -99.099325      Xochimilco   CDMX          2             0
# 1788  19.256973 -99.035680      Xochimilco   CDMX          1             0
#
#       airbnb_mean_price  flag_airbnb  flag_starbucks  valor_unitario_pred
# 0            756.684211            1               1          4746.374323
# 1           1033.310345            1               0          1602.655192
# 2            944.648649            1               1          3761.361499
# 3            506.333333            1               0          1572.603150
# 4            878.545455            1               0          1581.148991
# ...                 ...          ...             ...                  ...
# 1784           0.000000            0               0          1625.301504
# 1785         391.500000            1               0          1626.442113
# 1786           0.000000            0               0          1625.301504
# 1787        5009.000000            1               0          1611.034536
# 1788         453.000000            1               0          1625.013422
#
# [1789 rows x 13 columns]

# %%
catastro_df_ml.to_csv('catastro_ml_model_radio700_results.csv', index = False)

# %% [markdown]
# # Classification model testing

# %% [markdown]
# ## Decision Tree Models

# %% [markdown]
# ### Decision Tree Classifier for Airbnbs

# %%
# Encode categorical columns
le = LabelEncoder()
catastro_encode = catastro_df_ml.copy()
catastro_encode['alcaldia'] = le.fit_transform(catastro_encode['alcaldia'])
catastro_encode['nombre_col'] = le.fit_transform(catastro_encode['nombre_col'])
catastro_encode = catastro_encode.fillna(0)

# Define feature set and target set
X = catastro_encode.copy()
X = X.drop(['estado','flag_airbnb','latitud','longitud','valor_unitario_pred'], axis = 1)
y = catastro_encode['flag_airbnb'].values

# Split the data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# Scale the training and testing data
scaler = StandardScaler()
X_scaler = scaler.fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Fit the decision tree model
model = tree.DecisionTreeClassifier()
model = model.fit(X_train_scaled, y_train)

# Generate Predictions
predictions = model.predict(X_test_scaled)

# Evaluate the model
cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(cm, index = ['Actual 0', 'Actual 1'], columns =['Predicted 0','Predicted 1'])

# Calculate accuracy score
acc_score = accuracy_score(y_test, predictions)

# Display Results
print('Decision Tree Results')
print('Confusion Matrix')
display(cm_df)
print(f'Accuracy Score:{acc_score}')
print('Classification Report')
print(classification_report(y_test, predictions))
# Out:
# Decision Tree Results
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0           22            0
# Actual 1            0          336
# Accuracy Score:1.0
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        22
#            1       1.00      1.00      1.00       336
#
#     accuracy                           1.00       358
#    macro avg       1.00      1.00      1.00       358
# weighted avg       1.00      1.00      1.00       358

# %% [markdown]
# ### Decision Tree Classifier for Starbucks

# %%
# Define feature set and target set
X = catastro_encode.copy()
X = X.drop(['estado','flag_starbucks','latitud','longitud'], axis = 1)
y = catastro_encode['flag_starbucks'].values

# Split the data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, stratify = y)

# Scale the training and testing data
scaler = StandardScaler()
X_scaler = scaler.fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Fit the decision tree model
model = tree.DecisionTreeClassifier()
model = model.fit(X_train_scaled, y_train)

# Generate Predictions
predictions = model.predict(X_test_scaled)

# Evaluate the model
cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(cm, index = ['Actual 0', 'Actual 1'], columns =['Predicted 0','Predicted 1'])

# Calculate accuracy score
acc_score = accuracy_score(y_test, predictions)

# Display Results
print('Confusion Matrix')
display(cm_df)
print(f'Accuracy Score:{acc_score}')
print('Classification Report')
print(classification_report(y_test, predictions))
# Out:
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0          235            0
# Actual 1            0          123
# Accuracy Score:1.0
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       235
#            1       1.00      1.00      1.00       123
#
#     accuracy                           1.00       358
#    macro avg       1.00      1.00      1.00       358
# weighted avg       1.00      1.00      1.00       358

# %% [markdown]
# ## Random Forest Models

# %% [markdown]
# ### Random Forest Classifier for Airbnbs

# %%
# Encode categorical columns
le = LabelEncoder()
catastro_encode = catastro_df.copy()
catastro_encode['alcaldia'] = le.fit_transform(catastro_encode['alcaldia'])

# Define feature set and target set
X = catastro_encode.copy()
X = X.drop(['nombre_col','estado','flag_airbnb','latitud','longitud'], axis = 1)
y = catastro_encode['flag_airbnb'].values

# Split the data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, stratify = y)

# Scale the training and testing data
scaler = StandardScaler()
X_scaler = scaler.fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Create a Random Forest Classifier Instance
rf_model_bnb = RandomForestClassifier(n_estimators = 128, random_state = 72)

# Fit the model
rf_model_bnb = rf_model_bnb.fit(X_train_scaled, y_train)

# Make predictions using the testing data
predictions = rf_model_bnb.predict(X_test_scaled)

# Evaluate the model
cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(cm, index = ['Actual 0', 'Actual 1'], columns =['Predicted 0','Predicted 1'])

# Display Results
print('Random Forest Classifier Results')
print('Confusion Matrix')
display(cm_df)
print(f'Accuracy Score:{acc_score}')
print('Classification Report')
print(classification_report(y_test, predictions))
# Out:
# Random Forest Classifier Results
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0           25            0
# Actual 1            0          333
# Accuracy Score:1.0
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        25
#            1       1.00      1.00      1.00       333
#
#     accuracy                           1.00       358
#    macro avg       1.00      1.00      1.00       358
# weighted avg       1.00      1.00      1.00       358

# %% [markdown]
# ### Random Forest Classifier for Starbucks

# %%
# Define feature set and target set
X = catastro_encode.copy()
X = X.drop(['nombre_col','estado','flag_starbucks','latitud','longitud'], axis = 1)
y = catastro_encode['flag_starbucks'].values

# Split the data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, stratify = y)

# Scale the training and testing data
scaler = StandardScaler()
X_scaler = scaler.fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Create a Random Forest Classifier Instance
rf_model_starbucks = RandomForestClassifier(n_estimators = 128, random_state = 72)

# Fit the model
rf_model_starbucks = rf_model_starbucks.fit(X_train_scaled, y_train)

# Make predictions using the testing data
predictions = rf_model_starbucks.predict(X_test_scaled)

# Evaluate the model
cm = confusion_matrix(y_test, predictions)
cm_df = pd.DataFrame(cm, index = ['Actual 0', 'Actual 1'], columns =['Predicted 0','Predicted 1'])

# Display Results
print('Random Forest Classifier Results')
print('Confusion Matrix')
display(cm_df)
print(f'Accuracy Score:{acc_score}')
print('Classification Report')
print(classification_report(y_test, predictions))
# Out:
# Random Forest Classifier Results
# Confusion Matrix
#           Predicted 0  Predicted 1
# Actual 0          235            0
# Actual 1            0          123
# Accuracy Score:1.0
# Classification Report
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       235
#            1       1.00      1.00      1.00       123
#
#     accuracy                           1.00       358
#    macro avg       1.00      1.00      1.00       358
# weighted avg       1.00      1.00      1.00       358

# %% [markdown]
# ## Gradient Boosting Model

# %% [markdown]
# ### Gradient Boosting Classifier for Airbnbs

# %%
# Encode categorical columns
le = LabelEncoder()
catastro_encode = catastro_df.copy()
catastro_encode['alcaldia'] = le.fit_transform(catastro_encode['alcaldia'])
catastro_encode = catastro_encode.drop(columns = ['nombre_col','Unnamed: 0','estado'])

# Define feature set and target set
X = catastro_encode.copy()
X = X.drop('flag_airbnb', axis = 1)
y = catastro_encode['flag_airbnb'].values

# Split the data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, stratify = y)

# Scale the training and testing data
scaler = StandardScaler()
X_scaler = scaler.fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Try Different Learning Rates
learning_rates = [0.05,0.07,0.1,0.15,0.20,0.25,0.30,0.35,0.40,
                  0.45,0.5,0.55,0.60,0.65,0.70,0.75,0.80,0.85,0.90,0.95,1]

for learning_rates in learning_rates:
    
    # Iterate Gradient Booster Model
    classifier = GradientBoostingClassifier(n_estimators = 20, learning_rate = learning_rates,
                                            max_features = 9, max_depth = 3, random_state = 0)
    
    # Fit the Model
    classifier.fit(X_train_scaled, y_train)
    
    # Print Report
    print('Learning Rate: ', learning_rate)
    print('Accuracy Score (training): {0:.3f}'.format(classifier.score(X_train_scaled, y_train)))
    print('Accuracy Score (Validation): {0:.3f}'.format(classifier.score(X_test_scaled, y_test)))

# %%
# Select the Learning Rate with better results
classifier = GradientBoostingClassifier(n_estimators = 20, learning_rate = #TBD,
                                        ,max_features = 9, max_depth = 3, random_state = 0)

classifier.fit(X_train_scaled, y_train)
predictions = classifier.predict(X_test_scaled)
acc_score = accuracy_score(y_test, predictions)
print(f'Accuracy Score: {acc_score}')

cm = confusion_matrix(y_test, predictions)

# Create a DataFrame from the confusion matrix
cm_df = pd.DataFrame(cm, index = ['Actual 0', 'Actual 1'], columns =['Predicted 0','Predicted 1'])

# Display Results
print('Gradient Boosting Classifier Results')
print('Confusion Matrix')
display(cm_df)
print(f'Accuracy Score:{acc_score}')
print('Classification Report')
print(classification_report(y_test, predictions))

# %% [markdown]
# ### Gradient Boosting Classifier for Starbucks

# %%
# Encode categorical columns
le = LabelEncoder()
catastro_encode = catastro_df.copy()
catastro_encode['alcaldia'] = le.fit_transform(catastro_encode['alcaldia'])
catastro_encode = catastro_encode.drop(columns = ['nombre_col','Unnamed: 0','estado'])

# Define feature set and target set
X = catastro_encode.copy()
X = X.drop('flag_starbucks', axis = 1)
y = catastro_encode['flag_starbucks'].values

# Split the data into training and testing
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, stratify = y)

# Scale the training and testing data
scaler = StandardScaler()
X_scaler = scaler.fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Try Different Learning Rates
learning_rates = [0.05,0.07,0.1,0.15,0.20,0.25,0.30,0.35,0.40,
                  0.45,0.5,0.55,0.60,0.65,0.70,0.75,0.80,0.85,0.90,0.95,1]

for learning_rates in learning_rates:
    
    # Iterate Gradient Booster Model
    classifier = GradientBoostingClassifier(n_estimators = 20, learning_rate = learning_rates,
                                            max_features = 9, max_depth = 3, random_state = 0)
    
    # Fit the Model
    classifier.fit(X_train_scaled, y_train)
    
    # Print Report
    print('Learning Rate: ', learning_rate)
    print('Accuracy Score (training): {0:.3f}'.format(classifier.score(X_train_scaled, y_train)))
    print('Accuracy Score (Validation): {0:.3f}'.format(classifier.score(X_test_scaled, y_test)))

# %%
# Select the Learning Rate with better results
classifier = GradientBoostingClassifier(n_estimators = 20, learning_rate = #TBD,
                                        ,max_features = 9, max_depth = 3, random_state = 0)

classifier.fit(X_train_scaled, y_train)
predictions = classifier.predict(X_test_scaled)
acc_score = accuracy_score(y_test, predictions)
print(f'Accuracy Score: {acc_score}')

cm = confusion_matrix(y_test, predictions)

# Create a DataFrame from the confusion matrix
cm_df = pd.DataFrame(cm, index = ['Actual 0', 'Actual 1'], columns =['Predicted 0','Predicted 1'])

# Display Results
print('Gradient Boosting Classifier Results')
print('Confusion Matrix')
display(cm_df)
print(f'Accuracy Score:{acc_score}')
print('Classification Report')
print(classification_report(y_test, predictions))
