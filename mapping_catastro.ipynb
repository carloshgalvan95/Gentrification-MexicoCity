# %%
# Making a geodataframe

# Import dependencies
import geopandas as gp
import pandas as pd

# %%
df = pd.read_csv('db_catastro.csv')

# %%
catastro_gp = gp.GeoDataFrame(df,
                             geometry = gp.points_from_xy(df.longitud, df.latitud),
                             crs=4326)

# %%
catastro_gp.plot()
# Out:
# <AxesSubplot:>

# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
import numpy as np

# %%
# Store the CSV you saved created in part one into a DataFrame.
catastro_df = pd.read_csv("db_catastro.csv")
catastro_df.head()
# Out:
#                        col_name  mun_code  prom_valor_unitario_suelo  \
# 0                    19 DE MAYO      1210                1404.400000
# 1                  1RA VICTORIA      1150                2061.619503
# 2  1RA VICTORIA SECCION BOSQUES      1150                1788.360000
# 3    2DA  JALALPA TEPITO (AMPL)      1260                1063.626266
# 4           2DA EL PIRUL (AMPL)      1210                1320.710000
#
#      latitud   longitud        alcaldia estado
# 0  19.361649 -99.253530  Álvaro Obregón   CDMX
# 1  19.386686 -99.201985  Álvaro Obregón   CDMX
# 2  19.387826 -99.197446  Álvaro Obregón   CDMX
# 3  19.375080 -99.233736  Álvaro Obregón   CDMX
# 4  19.379745 -99.242231  Álvaro Obregón   CDMX

# %%
#change to lowers
catastro_df['col_name']=catastro_df['col_name'].str.lower()
catastro_df
# Out:
#                                col_name  mun_code  prom_valor_unitario_suelo  \
# 0                            19 de mayo      1210                1404.400000
# 1                          1ra victoria      1150                2061.619503
# 2          1ra victoria seccion bosques      1150                1788.360000
# 3            2da  jalalpa tepito (ampl)      1260                1063.626266
# 4                   2da el pirul (ampl)      1210                1320.710000
# ...                                 ...       ...                        ...
# 1784                          guadalupe     16900                 420.703636
# 1785           nativitas la joya (ampl)     16900                 711.580672
# 1786  san francisco tlalnepantla (pblo)     16910                 338.647387
# 1787     santa cecilia tepetlapa (pblo)     16880                 534.238763
# 1788     san luis tlaxialtemalco (pblo)     16610                 667.526340
#
#         latitud   longitud        alcaldia estado
# 0     19.361649 -99.253530  Álvaro Obregón   CDMX
# 1     19.386686 -99.201985  Álvaro Obregón   CDMX
# 2     19.387826 -99.197446  Álvaro Obregón   CDMX
# 3     19.375080 -99.233736  Álvaro Obregón   CDMX
# 4     19.379745 -99.242231  Álvaro Obregón   CDMX
# ...         ...        ...             ...    ...
# 1784  19.218264 -99.120799      Xochimilco   CDMX
# 1785  19.237250 -99.093782      Xochimilco   CDMX
# 1786  19.197937 -99.122385      Xochimilco   CDMX
# 1787  19.217187 -99.099325      Xochimilco   CDMX
# 1788  19.256973 -99.035680      Xochimilco   CDMX
#
# [1789 rows x 7 columns]

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = catastro_df[["latitud", "longitud"]]
# Get the maximum temperature.
valor_suelo = catastro_df["prom_valor_unitario_suelo"]
# Assign the figure variable.
fig = gmaps.figure()
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=valor_suelo)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# https://github.com/DamianZAR/python_maps-layers/blob/main/Maps-layers-Python.ipynb
## import dependencies
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
#import shape
# https://data.opendatasoft.com/explore/dataset/georef-mexico-colonia%40public/export/?disjunctive.sta_code&disjunctive.sta_name&disjunctive.mun_code&disjunctive.mun_name&disjunctive.col_code&disjunctive.col_name&location=10,19.36077,-99.14801&basemap=jawg.streets
cdmx= gpd.read_file('cdmx/georef-mexico-colonia-millesime.shp')
cdmx
# Out:
#       year sta_code           sta_name mun_code          mun_name col_code  \
# 0     2019       09  Ciudad de MÃ©xico    09010  Ãlvaro ObregÃ³n   10-200
# 1     2019       09  Ciudad de MÃ©xico    09015       CuauhtÃ©moc   15-012
# 2     2019       09  Ciudad de MÃ©xico    09012           Tlalpan   12-204
# 3     2019       09  Ciudad de MÃ©xico    09012           Tlalpan   12-201
# 4     2019       09  Ciudad de MÃ©xico    09010  Ãlvaro ObregÃ³n   10-238
# ...    ...      ...                ...      ...               ...      ...
# 1810  2019       09  Ciudad de MÃ©xico    09003         CoyoacÃ¡n   03-009
# 1811  2019       09  Ciudad de MÃ©xico    09012           Tlalpan   12-013
# 1812  2019       09  Ciudad de MÃ©xico    09002      Azcapotzalco   02-006
# 1813  2019       09  Ciudad de MÃ©xico    09007        Iztapalapa   07-319
# 1814  2019       09  Ciudad de MÃ©xico    09007        Iztapalapa   07-092
#
#                                   col_name col_area_co col_type  \
# 0                              Santa Lucia         MEX  colonia
# 1               Ex Hipodromo De Peralvillo         MEX  colonia
# 2     Zapote-Luis Donaldo Colosio (U Habs)         MEX  colonia
# 3                                Xaxalipac         MEX  colonia
# 4                             Villa Verdun         MEX  colonia
# ...                                    ...         ...      ...
# 1810                  Bosques De Tetlameya         MEX  colonia
# 1811                             Belvedere         MEX  colonia
# 1812                                Arenal         MEX  colonia
# 1813                Carlos Pacheco (U Hab)         MEX  colonia
# 1814                    Huasipungo (U Hab)         MEX  colonia
#
#                                                geometry
# 0     POLYGON ((-99.25760 19.35510, -99.25754 19.355...
# 1     POLYGON ((-99.14022 19.46039, -99.14005 19.460...
# 2     POLYGON ((-99.17772 19.29994, -99.17774 19.299...
# 3     POLYGON ((-99.14485 19.18065, -99.14471 19.180...
# 4     POLYGON ((-99.25172 19.33917, -99.25170 19.339...
# ...                                                 ...
# 1810  POLYGON ((-99.15948 19.30381, -99.15938 19.303...
# 1811  POLYGON ((-99.22484 19.26676, -99.22521 19.266...
# 1812  POLYGON ((-99.15186 19.46803, -99.15176 19.467...
# 1813  POLYGON ((-99.03084 19.36307, -99.03080 19.363...
# 1814  POLYGON ((-99.07382 19.28951, -99.07249 19.289...
#
# [1815 rows x 10 columns]

# %%
cdmx.plot()
# Out:
# <AxesSubplot:>

# %%
#import shape
# https://datos.cdmx.gob.mx/dataset/coloniascdmx
#cdmx= gpd.read_file('colonias_iecm_2019/mgpc_2019.shp')
#cdmx

# %%
cdmx.dtypes
# Out:
# year             object
# sta_code         object
# sta_name         object
# mun_code         object
# mun_name         object
# col_code         object
# col_name         object
# col_area_co      object
# col_type         object
# geometry       geometry
# dtype: object

# %%
catastro_df.dtypes
# Out:
# col_name                      object
# mun_code                       int64
# prom_valor_unitario_suelo    float64
# latitud                      float64
# longitud                     float64
# alcaldia                      object
# estado                        object
# dtype: object

# %%
#Change data type
cdmx['mun_code'] = cdmx.mun_code.astype(int)

# %%
cdmx
# Out:
#       year sta_code           sta_name  mun_code          mun_name col_code  \
# 0     2019       09  Ciudad de MÃ©xico      9010  Ãlvaro ObregÃ³n   10-200
# 1     2019       09  Ciudad de MÃ©xico      9015       CuauhtÃ©moc   15-012
# 2     2019       09  Ciudad de MÃ©xico      9012           Tlalpan   12-204
# 3     2019       09  Ciudad de MÃ©xico      9012           Tlalpan   12-201
# 4     2019       09  Ciudad de MÃ©xico      9010  Ãlvaro ObregÃ³n   10-238
# ...    ...      ...                ...       ...               ...      ...
# 1810  2019       09  Ciudad de MÃ©xico      9003         CoyoacÃ¡n   03-009
# 1811  2019       09  Ciudad de MÃ©xico      9012           Tlalpan   12-013
# 1812  2019       09  Ciudad de MÃ©xico      9002      Azcapotzalco   02-006
# 1813  2019       09  Ciudad de MÃ©xico      9007        Iztapalapa   07-319
# 1814  2019       09  Ciudad de MÃ©xico      9007        Iztapalapa   07-092
#
#                                   col_name col_area_co col_type  \
# 0                              Santa Lucia         MEX  colonia
# 1               Ex Hipodromo De Peralvillo         MEX  colonia
# 2     Zapote-Luis Donaldo Colosio (U Habs)         MEX  colonia
# 3                                Xaxalipac         MEX  colonia
# 4                             Villa Verdun         MEX  colonia
# ...                                    ...         ...      ...
# 1810                  Bosques De Tetlameya         MEX  colonia
# 1811                             Belvedere         MEX  colonia
# 1812                                Arenal         MEX  colonia
# 1813                Carlos Pacheco (U Hab)         MEX  colonia
# 1814                    Huasipungo (U Hab)         MEX  colonia
#
#                                                geometry
# 0     POLYGON ((-99.25760 19.35510, -99.25754 19.355...
# 1     POLYGON ((-99.14022 19.46039, -99.14005 19.460...
# 2     POLYGON ((-99.17772 19.29994, -99.17774 19.299...
# 3     POLYGON ((-99.14485 19.18065, -99.14471 19.180...
# 4     POLYGON ((-99.25172 19.33917, -99.25170 19.339...
# ...                                                 ...
# 1810  POLYGON ((-99.15948 19.30381, -99.15938 19.303...
# 1811  POLYGON ((-99.22484 19.26676, -99.22521 19.266...
# 1812  POLYGON ((-99.15186 19.46803, -99.15176 19.467...
# 1813  POLYGON ((-99.03084 19.36307, -99.03080 19.363...
# 1814  POLYGON ((-99.07382 19.28951, -99.07249 19.289...
#
# [1815 rows x 10 columns]

# %%
cdmx.dtypes
# Out:
# year             object
# sta_code         object
# sta_name         object
# mun_code          int32
# mun_name         object
# col_code         object
# col_name         object
# col_area_co      object
# col_type         object
# geometry       geometry
# dtype: object

# %%
#drop columns from cdmx

cdmx_poly=cdmx.drop(['year', 'sta_code', 'sta_name','col_code', 'col_area_co', 'col_type'],axis = 1)

# %%
# view new file
cdmx_poly
# Out:
#       mun_code          mun_name                              col_name  \
# 0         9010  Ãlvaro ObregÃ³n                           Santa Lucia
# 1         9015       CuauhtÃ©moc            Ex Hipodromo De Peralvillo
# 2         9012           Tlalpan  Zapote-Luis Donaldo Colosio (U Habs)
# 3         9012           Tlalpan                             Xaxalipac
# 4         9010  Ãlvaro ObregÃ³n                          Villa Verdun
# ...        ...               ...                                   ...
# 1810      9003         CoyoacÃ¡n                  Bosques De Tetlameya
# 1811      9012           Tlalpan                             Belvedere
# 1812      9002      Azcapotzalco                                Arenal
# 1813      9007        Iztapalapa                Carlos Pacheco (U Hab)
# 1814      9007        Iztapalapa                    Huasipungo (U Hab)
#
#                                                geometry
# 0     POLYGON ((-99.25760 19.35510, -99.25754 19.355...
# 1     POLYGON ((-99.14022 19.46039, -99.14005 19.460...
# 2     POLYGON ((-99.17772 19.29994, -99.17774 19.299...
# 3     POLYGON ((-99.14485 19.18065, -99.14471 19.180...
# 4     POLYGON ((-99.25172 19.33917, -99.25170 19.339...
# ...                                                 ...
# 1810  POLYGON ((-99.15948 19.30381, -99.15938 19.303...
# 1811  POLYGON ((-99.22484 19.26676, -99.22521 19.266...
# 1812  POLYGON ((-99.15186 19.46803, -99.15176 19.467...
# 1813  POLYGON ((-99.03084 19.36307, -99.03080 19.363...
# 1814  POLYGON ((-99.07382 19.28951, -99.07249 19.289...
#
# [1815 rows x 4 columns]

# %%
#change to lowers
cdmx_poly['col_name']=cdmx_poly['col_name'].str.lower()
cdmx_poly
# Out:
#       mun_code          mun_name                              col_name  \
# 0         9010  Ãlvaro ObregÃ³n                           santa lucia
# 1         9015       CuauhtÃ©moc            ex hipodromo de peralvillo
# 2         9012           Tlalpan  zapote-luis donaldo colosio (u habs)
# 3         9012           Tlalpan                             xaxalipac
# 4         9010  Ãlvaro ObregÃ³n                          villa verdun
# ...        ...               ...                                   ...
# 1810      9003         CoyoacÃ¡n                  bosques de tetlameya
# 1811      9012           Tlalpan                             belvedere
# 1812      9002      Azcapotzalco                                arenal
# 1813      9007        Iztapalapa                carlos pacheco (u hab)
# 1814      9007        Iztapalapa                    huasipungo (u hab)
#
#                                                geometry
# 0     POLYGON ((-99.25760 19.35510, -99.25754 19.355...
# 1     POLYGON ((-99.14022 19.46039, -99.14005 19.460...
# 2     POLYGON ((-99.17772 19.29994, -99.17774 19.299...
# 3     POLYGON ((-99.14485 19.18065, -99.14471 19.180...
# 4     POLYGON ((-99.25172 19.33917, -99.25170 19.339...
# ...                                                 ...
# 1810  POLYGON ((-99.15948 19.30381, -99.15938 19.303...
# 1811  POLYGON ((-99.22484 19.26676, -99.22521 19.266...
# 1812  POLYGON ((-99.15186 19.46803, -99.15176 19.467...
# 1813  POLYGON ((-99.03084 19.36307, -99.03080 19.363...
# 1814  POLYGON ((-99.07382 19.28951, -99.07249 19.289...
#
# [1815 rows x 4 columns]

# %%
# Merge Not successful
df = pd.merge( catastro_df,cdmx_poly,how='left',left_on=['mun_code','col_name'],right_on=['mun_code','col_name'])
df
# Out:
#                              col_name_x  mun_code  prom_valor_unitario_suelo  \
# 0                            19 de mayo      1210                1404.400000
# 1                          1ra victoria      1150                2061.619503
# 2          1ra victoria seccion bosques      1150                1788.360000
# 3            2da  jalalpa tepito (ampl)      1260                1063.626266
# 4                   2da el pirul (ampl)      1210                1320.710000
# ...                                 ...       ...                        ...
# 1784                          guadalupe     16900                 420.703636
# 1785           nativitas la joya (ampl)     16900                 711.580672
# 1786  san francisco tlalnepantla (pblo)     16910                 338.647387
# 1787     santa cecilia tepetlapa (pblo)     16880                 534.238763
# 1788     san luis tlaxialtemalco (pblo)     16610                 667.526340
#
#         latitud   longitud        alcaldia estado mun_name col_name_y geometry
# 0     19.361649 -99.253530  Álvaro Obregón   CDMX      NaN        NaN     None
# 1     19.386686 -99.201985  Álvaro Obregón   CDMX      NaN        NaN     None
# 2     19.387826 -99.197446  Álvaro Obregón   CDMX      NaN        NaN     None
# 3     19.375080 -99.233736  Álvaro Obregón   CDMX      NaN        NaN     None
# 4     19.379745 -99.242231  Álvaro Obregón   CDMX      NaN        NaN     None
# ...         ...        ...             ...    ...      ...        ...      ...
# 1784  19.218264 -99.120799      Xochimilco   CDMX      NaN        NaN     None
# 1785  19.237250 -99.093782      Xochimilco   CDMX      NaN        NaN     None
# 1786  19.197937 -99.122385      Xochimilco   CDMX      NaN        NaN     None
# 1787  19.217187 -99.099325      Xochimilco   CDMX      NaN        NaN     None
# 1788  19.256973 -99.035680      Xochimilco   CDMX      NaN        NaN     None
#
# [1789 rows x 10 columns]

# %%
# Merge
df = pd.merge( catastro_df,cdmx_poly,how='left',on=['col_name'])
df
# Out:
#                                col_name  mun_code_x  \
# 0                            19 de mayo        1210
# 1                          1ra victoria        1150
# 2          1ra victoria seccion bosques        1150
# 3            2da  jalalpa tepito (ampl)        1260
# 4                   2da el pirul (ampl)        1210
# ...                                 ...         ...
# 1942                          guadalupe       16900
# 1943           nativitas la joya (ampl)       16900
# 1944  san francisco tlalnepantla (pblo)       16910
# 1945     santa cecilia tepetlapa (pblo)       16880
# 1946     san luis tlaxialtemalco (pblo)       16610
#
#       prom_valor_unitario_suelo    latitud   longitud        alcaldia estado  \
# 0                   1404.400000  19.361649 -99.253530  Álvaro Obregón   CDMX
# 1                   2061.619503  19.386686 -99.201985  Álvaro Obregón   CDMX
# 2                   1788.360000  19.387826 -99.197446  Álvaro Obregón   CDMX
# 3                   1063.626266  19.375080 -99.233736  Álvaro Obregón   CDMX
# 4                   1320.710000  19.379745 -99.242231  Álvaro Obregón   CDMX
# ...                         ...        ...        ...             ...    ...
# 1942                 420.703636  19.218264 -99.120799      Xochimilco   CDMX
# 1943                 711.580672  19.237250 -99.093782      Xochimilco   CDMX
# 1944                 338.647387  19.197937 -99.122385      Xochimilco   CDMX
# 1945                 534.238763  19.217187 -99.099325      Xochimilco   CDMX
# 1946                 667.526340  19.256973 -99.035680      Xochimilco   CDMX
#
#       mun_code_y          mun_name  \
# 0         9010.0  Ãlvaro ObregÃ³n
# 1         9010.0  Ãlvaro ObregÃ³n
# 2         9010.0  Ãlvaro ObregÃ³n
# 3         9010.0  Ãlvaro ObregÃ³n
# 4         9010.0  Ãlvaro ObregÃ³n
# ...          ...               ...
# 1942      9013.0        Xochimilco
# 1943      9013.0        Xochimilco
# 1944      9013.0        Xochimilco
# 1945      9013.0        Xochimilco
# 1946      9013.0        Xochimilco
#
#                                                geometry
# 0     POLYGON ((-99.25312 19.36428, -99.25239 19.364...
# 1     POLYGON ((-99.20419 19.38585, -99.20422 19.386...
# 2     POLYGON ((-99.19927 19.38646, -99.19944 19.386...
# 3     POLYGON ((-99.23047 19.38063, -99.23046 19.380...
# 4     POLYGON ((-99.24327 19.38031, -99.24191 19.380...
# ...                                                 ...
# 1942  POLYGON ((-99.11995 19.20529, -99.12015 19.205...
# 1943  POLYGON ((-99.09718 19.24208, -99.09686 19.241...
# 1944  POLYGON ((-99.11995 19.20529, -99.11972 19.205...
# 1945  POLYGON ((-99.10097 19.22516, -99.10071 19.225...
# 1946  POLYGON ((-99.03402 19.24948, -99.03409 19.249...
#
# [1947 rows x 10 columns]

# %%
df.dtypes
# Out:
# col_name                       object
# mun_code_x                      int64
# prom_valor_unitario_suelo     float64
# latitud                       float64
# longitud                      float64
# alcaldia                       object
# estado                         object
# mun_code_y                    float64
# mun_name                       object
# geometry                     geometry
# dtype: object

# %%
#convert into a GeoDataFrame
from geopandas import GeoDataFrame

df_poly = GeoDataFrame(df)

# %%
#drop columns from cdmx

df_poly=df.drop(['mun_code_x', 'latitud', 'longitud','alcaldia', 'estado', 'mun_code_y', 'mun_name'],axis = 1)
df_poly
# Out:
#                                col_name  prom_valor_unitario_suelo  \
# 0                            19 de mayo                1404.400000
# 1                          1ra victoria                2061.619503
# 2          1ra victoria seccion bosques                1788.360000
# 3            2da  jalalpa tepito (ampl)                1063.626266
# 4                   2da el pirul (ampl)                1320.710000
# ...                                 ...                        ...
# 1942                          guadalupe                 420.703636
# 1943           nativitas la joya (ampl)                 711.580672
# 1944  san francisco tlalnepantla (pblo)                 338.647387
# 1945     santa cecilia tepetlapa (pblo)                 534.238763
# 1946     san luis tlaxialtemalco (pblo)                 667.526340
#
#                                                geometry
# 0     POLYGON ((-99.25312 19.36428, -99.25239 19.364...
# 1     POLYGON ((-99.20419 19.38585, -99.20422 19.386...
# 2     POLYGON ((-99.19927 19.38646, -99.19944 19.386...
# 3     POLYGON ((-99.23047 19.38063, -99.23046 19.380...
# 4     POLYGON ((-99.24327 19.38031, -99.24191 19.380...
# ...                                                 ...
# 1942  POLYGON ((-99.11995 19.20529, -99.12015 19.205...
# 1943  POLYGON ((-99.09718 19.24208, -99.09686 19.241...
# 1944  POLYGON ((-99.11995 19.20529, -99.11972 19.205...
# 1945  POLYGON ((-99.10097 19.22516, -99.10071 19.225...
# 1946  POLYGON ((-99.03402 19.24948, -99.03409 19.249...
#
# [1947 rows x 3 columns]

# %%
df_poly= df_poly[~df_poly['geometry'].isnull()]
df_poly
# Out:
#                                col_name  prom_valor_unitario_suelo  \
# 0                            19 de mayo                1404.400000
# 1                          1ra victoria                2061.619503
# 2          1ra victoria seccion bosques                1788.360000
# 3            2da  jalalpa tepito (ampl)                1063.626266
# 4                   2da el pirul (ampl)                1320.710000
# ...                                 ...                        ...
# 1942                          guadalupe                 420.703636
# 1943           nativitas la joya (ampl)                 711.580672
# 1944  san francisco tlalnepantla (pblo)                 338.647387
# 1945     santa cecilia tepetlapa (pblo)                 534.238763
# 1946     san luis tlaxialtemalco (pblo)                 667.526340
#
#                                                geometry
# 0     POLYGON ((-99.25312 19.36428, -99.25239 19.364...
# 1     POLYGON ((-99.20419 19.38585, -99.20422 19.386...
# 2     POLYGON ((-99.19927 19.38646, -99.19944 19.386...
# 3     POLYGON ((-99.23047 19.38063, -99.23046 19.380...
# 4     POLYGON ((-99.24327 19.38031, -99.24191 19.380...
# ...                                                 ...
# 1942  POLYGON ((-99.11995 19.20529, -99.12015 19.205...
# 1943  POLYGON ((-99.09718 19.24208, -99.09686 19.241...
# 1944  POLYGON ((-99.11995 19.20529, -99.11972 19.205...
# 1945  POLYGON ((-99.10097 19.22516, -99.10071 19.225...
# 1946  POLYGON ((-99.03402 19.24948, -99.03409 19.249...
#
# [1867 rows x 3 columns]

# %%
df_poly.dtypes
# Out:
# col_name                       object
# prom_valor_unitario_suelo     float64
# geometry                     geometry
# dtype: object

# %%
df_poly['prom_valor_unitario_suelo'] = df_poly.prom_valor_unitario_suelo.astype(float)
# Out:
# D:\Users\raul.esqueda\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_poly.dtypes
# Out:
# col_name                       object
# prom_valor_unitario_suelo     float64
# geometry                     geometry
# dtype: object

# %%
df_poly
# Out:
#                                col_name  prom_valor_unitario_suelo  \
# 0                            19 de mayo                1404.400000
# 1                          1ra victoria                2061.619503
# 2          1ra victoria seccion bosques                1788.360000
# 3            2da  jalalpa tepito (ampl)                1063.626266
# 4                   2da el pirul (ampl)                1320.710000
# ...                                 ...                        ...
# 1942                          guadalupe                 420.703636
# 1943           nativitas la joya (ampl)                 711.580672
# 1944  san francisco tlalnepantla (pblo)                 338.647387
# 1945     santa cecilia tepetlapa (pblo)                 534.238763
# 1946     san luis tlaxialtemalco (pblo)                 667.526340
#
#                                                geometry
# 0     POLYGON ((-99.25312 19.36428, -99.25239 19.364...
# 1     POLYGON ((-99.20419 19.38585, -99.20422 19.386...
# 2     POLYGON ((-99.19927 19.38646, -99.19944 19.386...
# 3     POLYGON ((-99.23047 19.38063, -99.23046 19.380...
# 4     POLYGON ((-99.24327 19.38031, -99.24191 19.380...
# ...                                                 ...
# 1942  POLYGON ((-99.11995 19.20529, -99.12015 19.205...
# 1943  POLYGON ((-99.09718 19.24208, -99.09686 19.241...
# 1944  POLYGON ((-99.11995 19.20529, -99.11972 19.205...
# 1945  POLYGON ((-99.10097 19.22516, -99.10071 19.225...
# 1946  POLYGON ((-99.03402 19.24948, -99.03409 19.249...
#
# [1867 rows x 3 columns]

# %%
base= cdmx.plot(color='none', edgecolor='lightgrey')
df_poly.plot(column="prom_valor_unitario_suelo", color='blue')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16884\3168893966.py in <module>
#       1 base= cdmx.plot(color='none', edgecolor='lightgrey')
# ----> 2 df_poly.plot(column="prom_valor_unitario_suelo", color='blue')
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     286         self._compute_plot_data()
#     287         self._setup_subplots()
# --> 288         self._make_plot()
#     289         self._add_table()
#     290         self._make_legend()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\core.py in _make_plot(self)
#    1188                 stacking_id=stacking_id,
#    1189                 is_errorbar=is_errorbar,
# -> 1190                 **kwds,
#    1191             )
#    1192             self._append_legend_handles_labels(newlines[0], label)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\core.py in _plot(cls, ax, x, y, style, column_num, stacking_id, **kwds)
#    1209             cls._initialize_stacker(ax, stacking_id, len(y))
#    1210         y_values = cls._get_stacked_values(ax, stacking_id, y, kwds["label"])
# -> 1211         lines = MPLPlot._plot(ax, x, y_values, style=style, **kwds)
#    1212         cls._update_stacker(ax, stacking_id, y)
#    1213         return lines
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\converter.py in wrapper(*args, **kwargs)
#      85     def wrapper(*args, **kwargs):
#      86         with pandas_converters():
# ---> 87             return func(*args, **kwargs)
#      88
#      89     return wrapper
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\core.py in _plot(cls, ax, x, y, style, is_errorbar, **kwds)
#     709             # prevent style kwarg from going to errorbar, where it is unsupported
#     710             args = (x, y, style) if style is not None else (x, y)
# --> 711             return ax.plot(*args, **kwds)
#     712
#     713     def _get_index_name(self) -> str | None:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     536             return list(result)
#     537         else:
# --> 538             return [l[0] for l in result]
#     539
#     540
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in <listcomp>(.0)
#     536             return list(result)
#     537         else:
# --> 538             return [l[0] for l in result]
#     539
#     540
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in <genexpr>(.0)
#     531         result = (make_artist(x[:, j % ncx], y[:, j % ncy], kw,
#     532                               {**kwargs, 'label': label})
# --> 533                   for j, label in enumerate(labels))
#     534
#     535         if return_kwargs:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in _makeline(self, x, y, kw, kwargs)
#     349         default_dict = self._getdefaults(set(), kw)
#     350         self._setdefaults(default_dict, kw)
# --> 351         seg = mlines.Line2D(x, y, **kw)
#     352         return seg, kw
#     353
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     391         # update kwargs before updating data to give the caller a
#     392         # chance to init axes (and hence unit support)
# --> 393         self.update(kwargs)
#     394         self.pickradius = pickradius
#     395         self.ind_offset = 0
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1062                     func = getattr(self, f"set_{k}", None)
#    1063                     if not callable(func):
# -> 1064                         raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                              f"has no property {k!r}")
#    1066                     ret.append(func(v))
#
# AttributeError: 'Line2D' object has no property 'column'

# %%
import matplotlib.pyplot as plt

# %%
df_poly.set_index('prom_valor_unitario_suelo')
# Out:
#                                                     col_name  \
# prom_valor_unitario_suelo
# 1404.400000                                       19 de mayo
# 2061.619503                                     1ra victoria
# 1788.360000                     1ra victoria seccion bosques
# 1063.626266                       2da  jalalpa tepito (ampl)
# 1320.710000                              2da el pirul (ampl)
# ...                                                      ...
# 420.703636                                         guadalupe
# 711.580672                          nativitas la joya (ampl)
# 338.647387                 san francisco tlalnepantla (pblo)
# 534.238763                    santa cecilia tepetlapa (pblo)
# 667.526340                    san luis tlaxialtemalco (pblo)
#
#                                                                     geometry
# prom_valor_unitario_suelo
# 1404.400000                POLYGON ((-99.25312 19.36428, -99.25239 19.364...
# 2061.619503                POLYGON ((-99.20419 19.38585, -99.20422 19.386...
# 1788.360000                POLYGON ((-99.19927 19.38646, -99.19944 19.386...
# 1063.626266                POLYGON ((-99.23047 19.38063, -99.23046 19.380...
# 1320.710000                POLYGON ((-99.24327 19.38031, -99.24191 19.380...
# ...                                                                      ...
# 420.703636                 POLYGON ((-99.11995 19.20529, -99.12015 19.205...
# 711.580672                 POLYGON ((-99.09718 19.24208, -99.09686 19.241...
# 338.647387                 POLYGON ((-99.11995 19.20529, -99.11972 19.205...
# 534.238763                 POLYGON ((-99.10097 19.22516, -99.10071 19.225...
# 667.526340                 POLYGON ((-99.03402 19.24948, -99.03409 19.249...
#
# [1867 rows x 2 columns]

# %%
fig, ax = plt.subplots(figsize = (10,10))
cdmx.to_crs(epsg=4326).plot(ax=ax, color='lightgrey')
catastro_df.plot(column='prom_valor_unitario_suelo')
ax.set_title('Kings County Real Estate')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16884\1902975130.py in <module>
#       1 fig, ax = plt.subplots(figsize = (10,10))
#       2 cdmx.to_crs(epsg=4326).plot(ax=ax, color='lightgrey')
# ----> 3 catastro_df.plot(column='prom_valor_unitario_suelo')
#       4 ax.set_title('Kings County Real Estate')
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     286         self._compute_plot_data()
#     287         self._setup_subplots()
# --> 288         self._make_plot()
#     289         self._add_table()
#     290         self._make_legend()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\core.py in _make_plot(self)
#    1188                 stacking_id=stacking_id,
#    1189                 is_errorbar=is_errorbar,
# -> 1190                 **kwds,
#    1191             )
#    1192             self._append_legend_handles_labels(newlines[0], label)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\core.py in _plot(cls, ax, x, y, style, column_num, stacking_id, **kwds)
#    1209             cls._initialize_stacker(ax, stacking_id, len(y))
#    1210         y_values = cls._get_stacked_values(ax, stacking_id, y, kwds["label"])
# -> 1211         lines = MPLPlot._plot(ax, x, y_values, style=style, **kwds)
#    1212         cls._update_stacker(ax, stacking_id, y)
#    1213         return lines
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\converter.py in wrapper(*args, **kwargs)
#      85     def wrapper(*args, **kwargs):
#      86         with pandas_converters():
# ---> 87             return func(*args, **kwargs)
#      88
#      89     return wrapper
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\core.py in _plot(cls, ax, x, y, style, is_errorbar, **kwds)
#     709             # prevent style kwarg from going to errorbar, where it is unsupported
#     710             args = (x, y, style) if style is not None else (x, y)
# --> 711             return ax.plot(*args, **kwds)
#     712
#     713     def _get_index_name(self) -> str | None:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     536             return list(result)
#     537         else:
# --> 538             return [l[0] for l in result]
#     539
#     540
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in <listcomp>(.0)
#     536             return list(result)
#     537         else:
# --> 538             return [l[0] for l in result]
#     539
#     540
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in <genexpr>(.0)
#     531         result = (make_artist(x[:, j % ncx], y[:, j % ncy], kw,
#     532                               {**kwargs, 'label': label})
# --> 533                   for j, label in enumerate(labels))
#     534
#     535         if return_kwargs:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in _makeline(self, x, y, kw, kwargs)
#     349         default_dict = self._getdefaults(set(), kw)
#     350         self._setdefaults(default_dict, kw)
# --> 351         seg = mlines.Line2D(x, y, **kw)
#     352         return seg, kw
#     353
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     391         # update kwargs before updating data to give the caller a
#     392         # chance to init axes (and hence unit support)
# --> 393         self.update(kwargs)
#     394         self.pickradius = pickradius
#     395         self.ind_offset = 0
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1062                     func = getattr(self, f"set_{k}", None)
#    1063                     if not callable(func):
# -> 1064                         raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                              f"has no property {k!r}")
#    1066                     ret.append(func(v))
#
# AttributeError: 'Line2D' object has no property 'column'

# %%
fig = plt.figure(figsize=(9, 7))
ax = fig.add_subplot(111)

#Plot of the title
title = "Recorded incomes in Yucatan"
plt.title(title, fontsize=21)

#Map plotting
df_poly.plot(column='prom_valor_unitario_suelo',cmap = 'hot_r', ax = ax)

#Axes
ax.set_xlabel('Longitude', fontsize = 13)
ax.set_ylabel('Latitude', fontsize = 13)

#Bar features
min_s = min(df_poly['prom_valor_unitario_suelo'])
max_s = max(df_poly['prom_valor_unitario_suelo'])
bar = plt.cm.ScalarMappable(cmap='hot_r', norm=plt.Normalize(vmin = min_s , vmax=max_s))
bar._A = []
#Bar position
cax = plt.axes([0.9, 0.15, 0.03, 0.7])   #[xcoord, ycoord, width, long]
# Bar plotting
cbar = fig.colorbar(bar, cax=cax)
#Bar title
cbar.set_label('Incomes (USD)', fontsize = 12)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16884\3437346178.py in <module>
#       7
#       8 #Map plotting
# ----> 9 df_poly.plot(column='prom_valor_unitario_suelo',cmap = 'hot_r', ax = ax)
#      10
#      11 #Axes
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     286         self._compute_plot_data()
#     287         self._setup_subplots()
# --> 288         self._make_plot()
#     289         self._add_table()
#     290         self._make_legend()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\core.py in _make_plot(self)
#    1188                 stacking_id=stacking_id,
#    1189                 is_errorbar=is_errorbar,
# -> 1190                 **kwds,
#    1191             )
#    1192             self._append_legend_handles_labels(newlines[0], label)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\core.py in _plot(cls, ax, x, y, style, column_num, stacking_id, **kwds)
#    1209             cls._initialize_stacker(ax, stacking_id, len(y))
#    1210         y_values = cls._get_stacked_values(ax, stacking_id, y, kwds["label"])
# -> 1211         lines = MPLPlot._plot(ax, x, y_values, style=style, **kwds)
#    1212         cls._update_stacker(ax, stacking_id, y)
#    1213         return lines
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\converter.py in wrapper(*args, **kwargs)
#      85     def wrapper(*args, **kwargs):
#      86         with pandas_converters():
# ---> 87             return func(*args, **kwargs)
#      88
#      89     return wrapper
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\core.py in _plot(cls, ax, x, y, style, is_errorbar, **kwds)
#     709             # prevent style kwarg from going to errorbar, where it is unsupported
#     710             args = (x, y, style) if style is not None else (x, y)
# --> 711             return ax.plot(*args, **kwds)
#     712
#     713     def _get_index_name(self) -> str | None:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     536             return list(result)
#     537         else:
# --> 538             return [l[0] for l in result]
#     539
#     540
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in <listcomp>(.0)
#     536             return list(result)
#     537         else:
# --> 538             return [l[0] for l in result]
#     539
#     540
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in <genexpr>(.0)
#     531         result = (make_artist(x[:, j % ncx], y[:, j % ncy], kw,
#     532                               {**kwargs, 'label': label})
# --> 533                   for j, label in enumerate(labels))
#     534
#     535         if return_kwargs:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in _makeline(self, x, y, kw, kwargs)
#     349         default_dict = self._getdefaults(set(), kw)
#     350         self._setdefaults(default_dict, kw)
# --> 351         seg = mlines.Line2D(x, y, **kw)
#     352         return seg, kw
#     353
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     391         # update kwargs before updating data to give the caller a
#     392         # chance to init axes (and hence unit support)
# --> 393         self.update(kwargs)
#     394         self.pickradius = pickradius
#     395         self.ind_offset = 0
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1062                     func = getattr(self, f"set_{k}", None)
#    1063                     if not callable(func):
# -> 1064                         raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                              f"has no property {k!r}")
#    1066                     ret.append(func(v))
#
# AttributeError: 'Line2D' object has no property 'column'

# %%
df_poly2=df_poly
df_poly2['prom_valor_unitario_suelo'] = np.log(df_poly2['prom_valor_unitario_suelo'])

# %%
fig, ax = plt.subplots(figsize = (10,10))
cdmx.to_crs(epsg=4326).plot(ax=ax, color='lightgrey')
df_poly.plot(column = 'prom_valor_unitario_suelo', ax=ax, cmap = 'rainbow',
            legend = True, legend_kwds={'shrink': 0.3}, 
            markersize = 10)
ax.set_title('Kings County Price Heatmap')
plt.savefig('Heat Map')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16884\2473629074.py in <module>
#       3 df_poly.plot(column = 'prom_valor_unitario_suelo', ax=ax, cmap = 'rainbow',
#       4             legend = True, legend_kwds={'shrink': 0.3},
# ----> 5             markersize = 10)
#       6 ax.set_title('Kings County Price Heatmap')
#       7 plt.savefig('Heat Map')
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     286         self._compute_plot_data()
#     287         self._setup_subplots()
# --> 288         self._make_plot()
#     289         self._add_table()
#     290         self._make_legend()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\core.py in _make_plot(self)
#    1188                 stacking_id=stacking_id,
#    1189                 is_errorbar=is_errorbar,
# -> 1190                 **kwds,
#    1191             )
#    1192             self._append_legend_handles_labels(newlines[0], label)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\core.py in _plot(cls, ax, x, y, style, column_num, stacking_id, **kwds)
#    1209             cls._initialize_stacker(ax, stacking_id, len(y))
#    1210         y_values = cls._get_stacked_values(ax, stacking_id, y, kwds["label"])
# -> 1211         lines = MPLPlot._plot(ax, x, y_values, style=style, **kwds)
#    1212         cls._update_stacker(ax, stacking_id, y)
#    1213         return lines
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\converter.py in wrapper(*args, **kwargs)
#      85     def wrapper(*args, **kwargs):
#      86         with pandas_converters():
# ---> 87             return func(*args, **kwargs)
#      88
#      89     return wrapper
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\core.py in _plot(cls, ax, x, y, style, is_errorbar, **kwds)
#     709             # prevent style kwarg from going to errorbar, where it is unsupported
#     710             args = (x, y, style) if style is not None else (x, y)
# --> 711             return ax.plot(*args, **kwds)
#     712
#     713     def _get_index_name(self) -> str | None:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     536             return list(result)
#     537         else:
# --> 538             return [l[0] for l in result]
#     539
#     540
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in <listcomp>(.0)
#     536             return list(result)
#     537         else:
# --> 538             return [l[0] for l in result]
#     539
#     540
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in <genexpr>(.0)
#     531         result = (make_artist(x[:, j % ncx], y[:, j % ncy], kw,
#     532                               {**kwargs, 'label': label})
# --> 533                   for j, label in enumerate(labels))
#     534
#     535         if return_kwargs:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in _makeline(self, x, y, kw, kwargs)
#     349         default_dict = self._getdefaults(set(), kw)
#     350         self._setdefaults(default_dict, kw)
# --> 351         seg = mlines.Line2D(x, y, **kw)
#     352         return seg, kw
#     353
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     391         # update kwargs before updating data to give the caller a
#     392         # chance to init axes (and hence unit support)
# --> 393         self.update(kwargs)
#     394         self.pickradius = pickradius
#     395         self.ind_offset = 0
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1062                     func = getattr(self, f"set_{k}", None)
#    1063                     if not callable(func):
# -> 1064                         raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                              f"has no property {k!r}")
#    1066                     ret.append(func(v))
#
# AttributeError: 'Line2D' object has no property 'column'

# %%
ig = plt.figure(figsize=(9, 7))
ax = fig.add_subplot(111)
#Título del mapa
title = 'PIB Per Capita (USD) de los países de Europa'
#Impresión del título indicando un renglón entre la figura y el #texto
plt.title(title + '\n', fontsize=19)
#Impresión del mapa indicando qué marco(ax) debe tomar de referencia
df_poly.plot(column='prom_valor_unitario_suelo', cmap = 'gist_rainbow', ax = ax)
#Nombre de los ejes horizontal y vertical
ax.set_xlabel('Longitud', fontsize = 13)
ax.set_ylabel('Latitud', fontsize = 13)
#Definición de los valores mínimo y máximo como límites de la barra #a utilizar
min_p = min(df_poly['prom_valor_unitario_suelo'])
max_p = max(df_poly['prom_valor_unitario_suelo'])
#Definición de la barra gráfica
bar = plt.cm.ScalarMappable(cmap='gist_rainbow', 
 norm=plt.Normalize(vmin = min_p , vmax=max_p))
#Se declara una lista donde se guardarán los valores de la barra
bar._A = []
#Declaración de la ubicación y el tamaño de la barra.
cax = plt.axes([0.85, 0.15, 0.03, 0.7]) #[xcoord, ycoord, ancho, largo]
# Impresión de la barra con las variables superiores (bar y cax)
cbar = fig.colorbar(bar, cax=cax)
#Título de la barra
cbar.set_label('PIB Per Capita (USD)', fontsize = 12)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16884\2140200341.py in <module>
#       6 plt.title(title + '\n', fontsize=19)
#       7 #Impresión del mapa indicando qué marco(ax) debe tomar de referencia
# ----> 8 df_poly.plot(column='prom_valor_unitario_suelo', cmap = 'gist_rainbow', ax = ax)
#       9 #Nombre de los ejes horizontal y vertical
#      10 ax.set_xlabel('Longitud', fontsize = 13)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     970                     data.columns = label_name
#     971
# --> 972         return plot_backend.plot(data, kind=kind, **kwargs)
#     973
#     974     __call__.__doc__ = __doc__
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71     plot_obj.generate()
#      72     plot_obj.draw()
#      73     return plot_obj.result
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     286         self._compute_plot_data()
#     287         self._setup_subplots()
# --> 288         self._make_plot()
#     289         self._add_table()
#     290         self._make_legend()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\core.py in _make_plot(self)
#    1188                 stacking_id=stacking_id,
#    1189                 is_errorbar=is_errorbar,
# -> 1190                 **kwds,
#    1191             )
#    1192             self._append_legend_handles_labels(newlines[0], label)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\core.py in _plot(cls, ax, x, y, style, column_num, stacking_id, **kwds)
#    1209             cls._initialize_stacker(ax, stacking_id, len(y))
#    1210         y_values = cls._get_stacked_values(ax, stacking_id, y, kwds["label"])
# -> 1211         lines = MPLPlot._plot(ax, x, y_values, style=style, **kwds)
#    1212         cls._update_stacker(ax, stacking_id, y)
#    1213         return lines
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\converter.py in wrapper(*args, **kwargs)
#      85     def wrapper(*args, **kwargs):
#      86         with pandas_converters():
# ---> 87             return func(*args, **kwargs)
#      88
#      89     return wrapper
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\plotting\_matplotlib\core.py in _plot(cls, ax, x, y, style, is_errorbar, **kwds)
#     709             # prevent style kwarg from going to errorbar, where it is unsupported
#     710             args = (x, y, style) if style is not None else (x, y)
# --> 711             return ax.plot(*args, **kwds)
#     712
#     713     def _get_index_name(self) -> str | None:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1630         """
#    1631         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1632         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633         for line in lines:
#    1634             self.add_line(line)
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     310                 this += args[0],
#     311                 args = args[1:]
# --> 312             yield from self._plot_args(this, kwargs)
#     313
#     314     def get_next_color(self):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     536             return list(result)
#     537         else:
# --> 538             return [l[0] for l in result]
#     539
#     540
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in <listcomp>(.0)
#     536             return list(result)
#     537         else:
# --> 538             return [l[0] for l in result]
#     539
#     540
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in <genexpr>(.0)
#     531         result = (make_artist(x[:, j % ncx], y[:, j % ncy], kw,
#     532                               {**kwargs, 'label': label})
# --> 533                   for j, label in enumerate(labels))
#     534
#     535         if return_kwargs:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\axes\_base.py in _makeline(self, x, y, kw, kwargs)
#     349         default_dict = self._getdefaults(set(), kw)
#     350         self._setdefaults(default_dict, kw)
# --> 351         seg = mlines.Line2D(x, y, **kw)
#     352         return seg, kw
#     353
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     391         # update kwargs before updating data to give the caller a
#     392         # chance to init axes (and hence unit support)
# --> 393         self.update(kwargs)
#     394         self.pickradius = pickradius
#     395         self.ind_offset = 0
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1062                     func = getattr(self, f"set_{k}", None)
#    1063                     if not callable(func):
# -> 1064                         raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                              f"has no property {k!r}")
#    1066                     ret.append(func(v))
#
# AttributeError: 'Line2D' object has no property 'column'
