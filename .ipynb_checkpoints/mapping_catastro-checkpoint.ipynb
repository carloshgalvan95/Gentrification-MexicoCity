# %%
# Making a geodataframe

# Import dependencies
import geopandas as gp
import pandas as pd

# %%
df = pd.read_csv('db_catastro.csv')

# %%
catastro_gp = gp.GeoDataFrame(df,
                             geometry = gp.points_from_xy(df.longitud, df.latitud),
                             crs=4326)

# %%
catastro_gp.plot()
# Out:
# <AxesSubplot:>

# %%
# Import the dependencies.
import pandas as pd
import gmaps
import requests
import numpy as np

# %%
# Store the CSV you saved created in part one into a DataFrame.
catastro_df = pd.read_csv("db_catastro.csv")
catastro_df.head()
# Out:
#    Unnamed: 0                    nombre_col  num_code  \
# 0           0                    19 DE MAYO      1210
# 1           1                  1RA VICTORIA      1150
# 2           2  1RA VICTORIA SECCION BOSQUES      1150
# 3           3    2DA  JALALPA TEPITO (AMPL)      1260
# 4           4           2DA EL PIRUL (AMPL)      1210
#
#    prom_valor_unitario_suelo    latitud   longitud        alcaldia estado
# 0                1404.400000  19.361649 -99.253530  Álvaro Obregón   CDMX
# 1                2061.619503  19.386686 -99.201985  Álvaro Obregón   CDMX
# 2                1788.360000  19.387826 -99.197446  Álvaro Obregón   CDMX
# 3                1063.626266  19.375080 -99.233736  Álvaro Obregón   CDMX
# 4                1320.710000  19.379745 -99.242231  Álvaro Obregón   CDMX

# %%
# Heatmap of temperature
# Get the latitude and longitude.
locations = catastro_df[["latitud", "longitud"]]
# Get the maximum temperature.
valor_suelo = catastro_df["prom_valor_unitario_suelo"]
# Assign the figure variable.
fig = gmaps.figure()
# Assign the heatmap variable.
heat_layer = gmaps.heatmap_layer(locations, weights=valor_suelo)
# Add the heatmap layer.
fig.add_layer(heat_layer)
# Call the figure to plot the data.
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# https://github.com/DamianZAR/python_maps-layers/blob/main/Maps-layers-Python.ipynb
## import dependencies
import geopandas as gpd
import matplotlib.pyplot as plt

# %%
#import shape
# https://data.opendatasoft.com/explore/dataset/georef-mexico-colonia%40public/export/?disjunctive.sta_code&disjunctive.sta_name&disjunctive.mun_code&disjunctive.mun_name&disjunctive.col_code&disjunctive.col_name&location=10,19.36077,-99.14801&basemap=jawg.streets
cdmx= gpd.read_file('cdmx/georef-mexico-colonia-millesime.shp')
cdmx
# Out:
#       year sta_code           sta_name mun_code          mun_name col_code  \
# 0     2019       09  Ciudad de MÃ©xico    09010  Ãlvaro ObregÃ³n   10-200
# 1     2019       09  Ciudad de MÃ©xico    09015       CuauhtÃ©moc   15-012
# 2     2019       09  Ciudad de MÃ©xico    09012           Tlalpan   12-204
# 3     2019       09  Ciudad de MÃ©xico    09012           Tlalpan   12-201
# 4     2019       09  Ciudad de MÃ©xico    09010  Ãlvaro ObregÃ³n   10-238
# ...    ...      ...                ...      ...               ...      ...
# 1810  2019       09  Ciudad de MÃ©xico    09003         CoyoacÃ¡n   03-009
# 1811  2019       09  Ciudad de MÃ©xico    09012           Tlalpan   12-013
# 1812  2019       09  Ciudad de MÃ©xico    09002      Azcapotzalco   02-006
# 1813  2019       09  Ciudad de MÃ©xico    09007        Iztapalapa   07-319
# 1814  2019       09  Ciudad de MÃ©xico    09007        Iztapalapa   07-092
#
#                                   col_name col_area_co col_type  \
# 0                              Santa Lucia         MEX  colonia
# 1               Ex Hipodromo De Peralvillo         MEX  colonia
# 2     Zapote-Luis Donaldo Colosio (U Habs)         MEX  colonia
# 3                                Xaxalipac         MEX  colonia
# 4                             Villa Verdun         MEX  colonia
# ...                                    ...         ...      ...
# 1810                  Bosques De Tetlameya         MEX  colonia
# 1811                             Belvedere         MEX  colonia
# 1812                                Arenal         MEX  colonia
# 1813                Carlos Pacheco (U Hab)         MEX  colonia
# 1814                    Huasipungo (U Hab)         MEX  colonia
#
#                                                geometry
# 0     POLYGON ((-99.25760 19.35510, -99.25754 19.355...
# 1     POLYGON ((-99.14022 19.46039, -99.14005 19.460...
# 2     POLYGON ((-99.17772 19.29994, -99.17774 19.299...
# 3     POLYGON ((-99.14485 19.18065, -99.14471 19.180...
# 4     POLYGON ((-99.25172 19.33917, -99.25170 19.339...
# ...                                                 ...
# 1810  POLYGON ((-99.15948 19.30381, -99.15938 19.303...
# 1811  POLYGON ((-99.22484 19.26676, -99.22521 19.266...
# 1812  POLYGON ((-99.15186 19.46803, -99.15176 19.467...
# 1813  POLYGON ((-99.03084 19.36307, -99.03080 19.363...
# 1814  POLYGON ((-99.07382 19.28951, -99.07249 19.289...
#
# [1815 rows x 10 columns]

# %%
#import shape
# https://datos.cdmx.gob.mx/dataset/coloniascdmx
#cdmx= gpd.read_file('colonias_iecm_2019/mgpc_2019.shp')
#cdmx

# %%
cdmx.dtypes
# Out:
# year             object
# sta_code         object
# sta_name         object
# mun_code         object
# mun_name         object
# col_code         object
# col_name         object
# col_area_co      object
# col_type         object
# geometry       geometry
# dtype: object

# %%
catastro_df.dtypes
# Out:
# Unnamed: 0                     int64
# nombre_col                    object
# num_code                       int64
# prom_valor_unitario_suelo    float64
# latitud                      float64
# longitud                     float64
# alcaldia                      object
# estado                        object
# dtype: object

# %%
#Change data type
catastro_df['num_code'] = catastro_df.num_code.astype(int)

# %%
catastro_df.dtypes
# Out:
# Unnamed: 0                     int64
# nombre_col                    object
# num_code                       int32
# prom_valor_unitario_suelo    float64
# latitud                      float64
# longitud                     float64
# alcaldia                      object
# estado                        object
# dtype: object

# %%
#Change data type
cdmx['mun_code'] = cdmx.mun_code.astype(int)

# %%
cdmx
# Out:
#       year sta_code           sta_name  mun_code          mun_name col_code  \
# 0     2019       09  Ciudad de MÃ©xico      9010  Ãlvaro ObregÃ³n   10-200
# 1     2019       09  Ciudad de MÃ©xico      9015       CuauhtÃ©moc   15-012
# 2     2019       09  Ciudad de MÃ©xico      9012           Tlalpan   12-204
# 3     2019       09  Ciudad de MÃ©xico      9012           Tlalpan   12-201
# 4     2019       09  Ciudad de MÃ©xico      9010  Ãlvaro ObregÃ³n   10-238
# ...    ...      ...                ...       ...               ...      ...
# 1810  2019       09  Ciudad de MÃ©xico      9003         CoyoacÃ¡n   03-009
# 1811  2019       09  Ciudad de MÃ©xico      9012           Tlalpan   12-013
# 1812  2019       09  Ciudad de MÃ©xico      9002      Azcapotzalco   02-006
# 1813  2019       09  Ciudad de MÃ©xico      9007        Iztapalapa   07-319
# 1814  2019       09  Ciudad de MÃ©xico      9007        Iztapalapa   07-092
#
#                                   col_name col_area_co col_type  \
# 0                              Santa Lucia         MEX  colonia
# 1               Ex Hipodromo De Peralvillo         MEX  colonia
# 2     Zapote-Luis Donaldo Colosio (U Habs)         MEX  colonia
# 3                                Xaxalipac         MEX  colonia
# 4                             Villa Verdun         MEX  colonia
# ...                                    ...         ...      ...
# 1810                  Bosques De Tetlameya         MEX  colonia
# 1811                             Belvedere         MEX  colonia
# 1812                                Arenal         MEX  colonia
# 1813                Carlos Pacheco (U Hab)         MEX  colonia
# 1814                    Huasipungo (U Hab)         MEX  colonia
#
#                                                geometry
# 0     POLYGON ((-99.25760 19.35510, -99.25754 19.355...
# 1     POLYGON ((-99.14022 19.46039, -99.14005 19.460...
# 2     POLYGON ((-99.17772 19.29994, -99.17774 19.299...
# 3     POLYGON ((-99.14485 19.18065, -99.14471 19.180...
# 4     POLYGON ((-99.25172 19.33917, -99.25170 19.339...
# ...                                                 ...
# 1810  POLYGON ((-99.15948 19.30381, -99.15938 19.303...
# 1811  POLYGON ((-99.22484 19.26676, -99.22521 19.266...
# 1812  POLYGON ((-99.15186 19.46803, -99.15176 19.467...
# 1813  POLYGON ((-99.03084 19.36307, -99.03080 19.363...
# 1814  POLYGON ((-99.07382 19.28951, -99.07249 19.289...
#
# [1815 rows x 10 columns]

# %%
cdmx.dtypes
# Out:
# year             object
# sta_code         object
# sta_name         object
# mun_code          int32
# mun_name         object
# col_code         object
# col_name         object
# col_area_co      object
# col_type         object
# geometry       geometry
# dtype: object

# %%
# Merge
df = pd.merge(catastro_df,cdmx,how='right',on='mun_code')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_53204\2528149486.py in <module>
#       1 # Merge
# ----> 2 df = pd.merge(catastro_df,cdmx,how='right',on='mun_code')
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     117         copy=copy,
#     118         indicator=indicator,
# --> 119         validate=validate,
#     120     )
#     121     return op.get_result()
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     697             self.right_join_keys,
#     698             self.join_names,
# --> 699         ) = self._get_merge_keys()
#     700
#     701         # validate the merge keys dtypes. We may need to coerce
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#    1107                         right_keys.append(rk)
#    1108                     if lk is not None:
# -> 1109                         left_keys.append(left._get_label_or_level_values(lk))
#    1110                         join_names.append(lk)
#    1111                     else:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1777             values = self.axes[axis].get_level_values(key)._values
#    1778         else:
# -> 1779             raise KeyError(key)
#    1780
#    1781         # Check for duplicates
#
# KeyError: 'mun_code'

# %%
df
# Out:
#          Unnamed: 0                      nombre_col  codigo_postal  \
# 0                 0                      19 DE MAYO           1210
# 1                 0                      19 DE MAYO           1210
# 2                 0                      19 DE MAYO           1210
# 3                 0                      19 DE MAYO           1210
# 4                 0                      19 DE MAYO           1210
# ...             ...                             ...            ...
# 3247030          77  SAN LUIS TLAXIALTEMALCO (PBLO)          16610
# 3247031          77  SAN LUIS TLAXIALTEMALCO (PBLO)          16610
# 3247032          77  SAN LUIS TLAXIALTEMALCO (PBLO)          16610
# 3247033          77  SAN LUIS TLAXIALTEMALCO (PBLO)          16610
# 3247034          77  SAN LUIS TLAXIALTEMALCO (PBLO)          16610
#
#          prom_valor_unitario_suelo    latitud  longitud        alcaldia  \
# 0                       1404.40000  19.361649 -99.25353  Álvaro Obregón
# 1                       1404.40000  19.361649 -99.25353  Álvaro Obregón
# 2                       1404.40000  19.361649 -99.25353  Álvaro Obregón
# 3                       1404.40000  19.361649 -99.25353  Álvaro Obregón
# 4                       1404.40000  19.361649 -99.25353  Álvaro Obregón
# ...                            ...        ...       ...             ...
# 3247030                  667.52634  19.256973 -99.03568      Xochimilco
# 3247031                  667.52634  19.256973 -99.03568      Xochimilco
# 3247032                  667.52634  19.256973 -99.03568      Xochimilco
# 3247033                  667.52634  19.256973 -99.03568      Xochimilco
# 3247034                  667.52634  19.256973 -99.03568      Xochimilco
#
#         estado  year sta_code           sta_name  mun_code          mun_name  \
# 0         CDMX  2019       09  Ciudad de MÃ©xico      9010  Ãlvaro ObregÃ³n
# 1         CDMX  2019       09  Ciudad de MÃ©xico      9015       CuauhtÃ©moc
# 2         CDMX  2019       09  Ciudad de MÃ©xico      9012           Tlalpan
# 3         CDMX  2019       09  Ciudad de MÃ©xico      9012           Tlalpan
# 4         CDMX  2019       09  Ciudad de MÃ©xico      9010  Ãlvaro ObregÃ³n
# ...        ...   ...      ...                ...       ...               ...
# 3247030   CDMX  2019       09  Ciudad de MÃ©xico      9003         CoyoacÃ¡n
# 3247031   CDMX  2019       09  Ciudad de MÃ©xico      9012           Tlalpan
# 3247032   CDMX  2019       09  Ciudad de MÃ©xico      9002      Azcapotzalco
# 3247033   CDMX  2019       09  Ciudad de MÃ©xico      9007        Iztapalapa
# 3247034   CDMX  2019       09  Ciudad de MÃ©xico      9007        Iztapalapa
#
#         col_code                              col_name col_area_co col_type  \
# 0         10-200                           Santa Lucia         MEX  colonia
# 1         15-012            Ex Hipodromo De Peralvillo         MEX  colonia
# 2         12-204  Zapote-Luis Donaldo Colosio (U Habs)         MEX  colonia
# 3         12-201                             Xaxalipac         MEX  colonia
# 4         10-238                          Villa Verdun         MEX  colonia
# ...          ...                                   ...         ...      ...
# 3247030   03-009                  Bosques De Tetlameya         MEX  colonia
# 3247031   12-013                             Belvedere         MEX  colonia
# 3247032   02-006                                Arenal         MEX  colonia
# 3247033   07-319                Carlos Pacheco (U Hab)         MEX  colonia
# 3247034   07-092                    Huasipungo (U Hab)         MEX  colonia
#
#                                                   geometry
# 0        POLYGON ((-99.25760 19.35510, -99.25754 19.355...
# 1        POLYGON ((-99.14022 19.46039, -99.14005 19.460...
# 2        POLYGON ((-99.17772 19.29994, -99.17774 19.299...
# 3        POLYGON ((-99.14485 19.18065, -99.14471 19.180...
# 4        POLYGON ((-99.25172 19.33917, -99.25170 19.339...
# ...                                                    ...
# 3247030  POLYGON ((-99.15948 19.30381, -99.15938 19.303...
# 3247031  POLYGON ((-99.22484 19.26676, -99.22521 19.266...
# 3247032  POLYGON ((-99.15186 19.46803, -99.15176 19.467...
# 3247033  POLYGON ((-99.03084 19.36307, -99.03080 19.363...
# 3247034  POLYGON ((-99.07382 19.28951, -99.07249 19.289...
#
# [3247035 rows x 18 columns]

# %%
#Plotting
fig = plt.figure(figsize=(9, 7))
ax = fig.add_subplot(111)

#Plot of the title
title = "Valor unitario del suelo promedio CDMX"
plt.title(title, fontsize=21)

#Map plotting
catastro.plot(column= (from.catastro_df('sales'=,  cmap = 'hot_r', ax = ax)

#Axes
ax.set_xlabel('Longitude', fontsize = 13)
ax.set_ylabel('Latitude', fontsize = 13)

#Bar features
min_s = min(yucatan['sales'])
max_s = max(yucatan['sales'])
bar = plt.cm.ScalarMappable(cmap='hot_r', norm=plt.Normalize(vmin = min_s , vmax=max_s))
bar._A = []
#Bar position
cax = plt.axes([0.9, 0.15, 0.03, 0.7])   #[xcoord, ycoord, width, long]
# Bar plotting
cbar = fig.colorbar(bar, cax=cax)
#Bar title
cbar.set_label('Incomes (USD)', fontsize = 12)
